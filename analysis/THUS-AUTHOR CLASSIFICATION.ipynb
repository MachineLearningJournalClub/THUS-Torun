# %% [markdown]
# # Nicolaus Copernicus University summer internship project
# ## Natural Language Processing applied to ancient language texts
#
# We aim to investigate the implementation of a general pipeline to extract qualitative and quantitative information from Latin texts employing ML algorithms. In particular, our approach focuses on detecting similarities between texts of the same author. For instance, it could
# be beneficial to classify authors according to writing styles or historical ages, as well as to recognize the author of anonymous documents with a certain probability. \\
#
# Finally, we propose a network representation that aims to capture and represent these similarities, and we quantify the degree of relationship by computing a similarity index.

# %%
#Install the necessary libraries
# !wget --no-check-certificate --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1Te_14UB-DZ8wYPhHGyDg7LadDTjNzpti' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1Te_14UB-DZ8wYPhHGyDg7LadDTjNzpti" -O latin_bert.tar && rm -f /tmp/cookies.txt
# !mkdir models
# !mv latin_bert.tar models/
# !cd models
# !tar -xf models/latin_bert.tar
# !git clone https://github.com/pietro-sillano/LatinBERT LatinBERT
# !pip install cltk==1.0.16
# !pip install pygame  beautifulsoup4==4.9.1 cltk nltk==3.6.2 future==0.18.2 numpy tensor2tensor PyYAML==5.4.1 tokenizers==0.8.1rc2 transformers==3.1.0 tqdm==4.48.2 Unidecode==1.1.1 gensim==3.8.3
# !pip install --upgrade scikit-learn
# !pip install --upgrade spacy
# !pip install --upgrade spacy
# !pip install umap-learn
# !pip install umap-learn[plot]
# Out:
# --2021-08-13 22:07:52--  https://docs.google.com/uc?export=download&confirm=YEnd&id=1Te_14UB-DZ8wYPhHGyDg7LadDTjNzpti
# Resolving docs.google.com (docs.google.com)... 142.250.141.139, 142.250.141.100, 142.250.141.102, ...
# Connecting to docs.google.com (docs.google.com)|142.250.141.139|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0g-80-docs.googleusercontent.com/docs/securesc/9tb3bu8tdta7s3i1klnr508gfsgdntt4/hjcujghcq5j3kc0qtc5n23elsvulo8er/1628892450000/09859182337762586004/14455568975331539655Z/1Te_14UB-DZ8wYPhHGyDg7LadDTjNzpti?e=download [following]
# --2021-08-13 22:07:53--  https://doc-0g-80-docs.googleusercontent.com/docs/securesc/9tb3bu8tdta7s3i1klnr508gfsgdntt4/hjcujghcq5j3kc0qtc5n23elsvulo8er/1628892450000/09859182337762586004/14455568975331539655Z/1Te_14UB-DZ8wYPhHGyDg7LadDTjNzpti?e=download
# Resolving doc-0g-80-docs.googleusercontent.com (doc-0g-80-docs.googleusercontent.com)... 142.250.141.132, 2607:f8b0:4023:c0b::84
# Connecting to doc-0g-80-docs.googleusercontent.com (doc-0g-80-docs.googleusercontent.com)|142.250.141.132|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://docs.google.com/nonceSigner?nonce=s24lp59kqnpm4&continue=https://doc-0g-80-docs.googleusercontent.com/docs/securesc/9tb3bu8tdta7s3i1klnr508gfsgdntt4/hjcujghcq5j3kc0qtc5n23elsvulo8er/1628892450000/09859182337762586004/14455568975331539655Z/1Te_14UB-DZ8wYPhHGyDg7LadDTjNzpti?e%3Ddownload&hash=6vrhcqtrv3k6fnjlcv2vn9daii858kla [following]
# --2021-08-13 22:07:53--  https://docs.google.com/nonceSigner?nonce=s24lp59kqnpm4&continue=https://doc-0g-80-docs.googleusercontent.com/docs/securesc/9tb3bu8tdta7s3i1klnr508gfsgdntt4/hjcujghcq5j3kc0qtc5n23elsvulo8er/1628892450000/09859182337762586004/14455568975331539655Z/1Te_14UB-DZ8wYPhHGyDg7LadDTjNzpti?e%3Ddownload&hash=6vrhcqtrv3k6fnjlcv2vn9daii858kla
# Connecting to docs.google.com (docs.google.com)|142.250.141.139|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://doc-0g-80-docs.googleusercontent.com/docs/securesc/9tb3bu8tdta7s3i1klnr508gfsgdntt4/hjcujghcq5j3kc0qtc5n23elsvulo8er/1628892450000/09859182337762586004/14455568975331539655Z/1Te_14UB-DZ8wYPhHGyDg7LadDTjNzpti?e=download&nonce=s24lp59kqnpm4&user=14455568975331539655Z&hash=nf4phandrv57t74u2uo7auhn1s3blp1l [following]
# --2021-08-13 22:07:53--  https://doc-0g-80-docs.googleusercontent.com/docs/securesc/9tb3bu8tdta7s3i1klnr508gfsgdntt4/hjcujghcq5j3kc0qtc5n23elsvulo8er/1628892450000/09859182337762586004/14455568975331539655Z/1Te_14UB-DZ8wYPhHGyDg7LadDTjNzpti?e=download&nonce=s24lp59kqnpm4&user=14455568975331539655Z&hash=nf4phandrv57t74u2uo7auhn1s3blp1l
# Connecting to doc-0g-80-docs.googleusercontent.com (doc-0g-80-docs.googleusercontent.com)|142.250.141.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/x-tar]
# Saving to: ‘latin_bert.tar’
#
# latin_bert.tar          [                <=> ] 427.27M   122MB/s    in 3.7s
#
# 2021-08-13 22:07:57 (115 MB/s) - ‘latin_bert.tar’ saved [448020480]
#
# mkdir: cannot create directory ‘models’: File exists
# fatal: destination path 'LatinBERT' already exists and is not an empty directory.
# Requirement already satisfied: cltk==1.0.16 in /usr/local/lib/python3.7/dist-packages (1.0.16)
# Requirement already satisfied: stringcase<2.0,>=1.2 in /usr/local/lib/python3.7/dist-packages (from cltk==1.0.16) (1.2.0)
# Requirement already satisfied: PyYAML<6.0.0,>=5.4.1 in /usr/local/lib/python3.7/dist-packages (from cltk==1.0.16) (5.4.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.41.1 in /usr/local/lib/python3.7/dist-packages (from cltk==1.0.16) (4.48.2)
# Requirement already satisfied: nltk<4.0,>=3.5 in /usr/local/lib/python3.7/dist-packages (from cltk==1.0.16) (3.6.2)
# Requirement already satisfied: greek-accentuation<2.0.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from cltk==1.0.16) (1.2.0)
# Requirement already satisfied: boltons<21.0.0,>=20.0.0 in /usr/local/lib/python3.7/dist-packages (from cltk==1.0.16) (20.2.1)
# Requirement already satisfied: stanza==1.1.1 in /usr/local/lib/python3.7/dist-packages (from cltk==1.0.16) (1.1.1)
# Requirement already satisfied: gitpython<4.0,>=3.0 in /usr/local/lib/python3.7/dist-packages (from cltk==1.0.16) (3.1.18)
# Requirement already satisfied: gensim<4.0.0,>=3.8.1 in /usr/local/lib/python3.7/dist-packages (from cltk==1.0.16) (3.8.3)
# Requirement already satisfied: fasttext<0.10.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from cltk==1.0.16) (0.9.2)
# Requirement already satisfied: scikit-learn<0.25.0,>=0.24.2 in /usr/local/lib/python3.7/dist-packages (from cltk==1.0.16) (0.24.2)
# Requirement already satisfied: python-Levenshtein<0.13.0,>=0.12.0 in /usr/local/lib/python3.7/dist-packages (from cltk==1.0.16) (0.12.2)
# Collecting spacy<3.0.0,>=2.3.5
#   Using cached spacy-2.3.7-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.4 MB)
# Requirement already satisfied: requests<3.0.0,>=2.22.0 in /usr/local/lib/python3.7/dist-packages (from cltk==1.0.16) (2.23.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from stanza==1.1.1->cltk==1.0.16) (3.17.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from stanza==1.1.1->cltk==1.0.16) (1.19.5)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from stanza==1.1.1->cltk==1.0.16) (1.9.0+cu102)
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.7/dist-packages (from fasttext<0.10.0,>=0.9.1->cltk==1.0.16) (2.7.1)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from fasttext<0.10.0,>=0.9.1->cltk==1.0.16) (57.2.0)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from gensim<4.0.0,>=3.8.1->cltk==1.0.16) (5.1.0)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from gensim<4.0.0,>=3.8.1->cltk==1.0.16) (1.15.0)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim<4.0.0,>=3.8.1->cltk==1.0.16) (1.4.1)
# Requirement already satisfied: typing-extensions>=3.7.4.0 in /usr/local/lib/python3.7/dist-packages (from gitpython<4.0,>=3.0->cltk==1.0.16) (3.7.4.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from gitpython<4.0,>=3.0->cltk==1.0.16) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from gitdb<5,>=4.0.1->gitpython<4.0,>=3.0->cltk==1.0.16) (4.0.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk<4.0,>=3.5->cltk==1.0.16) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk<4.0,>=3.5->cltk==1.0.16) (1.0.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from nltk<4.0,>=3.5->cltk==1.0.16) (2019.12.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.22.0->cltk==1.0.16) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.22.0->cltk==1.0.16) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.22.0->cltk==1.0.16) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.22.0->cltk==1.0.16) (3.0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<0.25.0,>=0.24.2->cltk==1.0.16) (2.2.0)
# Collecting thinc<7.5.0,>=7.4.1
#   Using cached thinc-7.4.5-cp37-cp37m-manylinux2014_x86_64.whl (1.0 MB)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.3.5->cltk==1.0.16) (2.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.3.5->cltk==1.0.16) (1.0.5)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.3.5->cltk==1.0.16) (0.4.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.3.5->cltk==1.0.16) (0.8.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.3.5->cltk==1.0.16) (3.0.5)
# Collecting catalogue<1.1.0,>=0.0.7
#   Using cached catalogue-1.0.0-py2.py3-none-any.whl (7.7 kB)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.3.5->cltk==1.0.16) (1.1.3)
# Collecting srsly<1.1.0,>=1.0.2
#   Using cached srsly-1.0.5-cp37-cp37m-manylinux2014_x86_64.whl (184 kB)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy<3.0.0,>=2.3.5->cltk==1.0.16) (4.6.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<3.0.0,>=2.3.5->cltk==1.0.16) (3.5.0)
# Installing collected packages: srsly, catalogue, thinc, spacy
#   Attempting uninstall: srsly
#     Found existing installation: srsly 2.4.1
#     Uninstalling srsly-2.4.1:
#       Successfully uninstalled srsly-2.4.1
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 2.0.5
#     Uninstalling catalogue-2.0.5:
#       Successfully uninstalled catalogue-2.0.5
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.0.8
#     Uninstalling thinc-8.0.8:
#       Successfully uninstalled thinc-8.0.8
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.1.1
#     Uninstalling spacy-3.1.1:
#       Successfully uninstalled spacy-3.1.1
# Successfully installed catalogue-1.0.0 spacy-2.3.7 srsly-1.0.5 thinc-7.4.5
# Requirement already satisfied: pygame in /usr/local/lib/python3.7/dist-packages (2.0.1)
# Requirement already satisfied: beautifulsoup4==4.9.1 in /usr/local/lib/python3.7/dist-packages (4.9.1)
# Requirement already satisfied: cltk in /usr/local/lib/python3.7/dist-packages (1.0.16)
# Requirement already satisfied: nltk==3.6.2 in /usr/local/lib/python3.7/dist-packages (3.6.2)
# Requirement already satisfied: future==0.18.2 in /usr/local/lib/python3.7/dist-packages (0.18.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (1.19.5)
# Requirement already satisfied: tensor2tensor in /usr/local/lib/python3.7/dist-packages (1.15.7)
# Requirement already satisfied: PyYAML==5.4.1 in /usr/local/lib/python3.7/dist-packages (5.4.1)
# Requirement already satisfied: tokenizers==0.8.1rc2 in /usr/local/lib/python3.7/dist-packages (0.8.1rc2)
# Requirement already satisfied: transformers==3.1.0 in /usr/local/lib/python3.7/dist-packages (3.1.0)
# Requirement already satisfied: tqdm==4.48.2 in /usr/local/lib/python3.7/dist-packages (4.48.2)
# Requirement already satisfied: Unidecode==1.1.1 in /usr/local/lib/python3.7/dist-packages (1.1.1)
# Requirement already satisfied: gensim==3.8.3 in /usr/local/lib/python3.7/dist-packages (3.8.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.7/dist-packages (from beautifulsoup4==4.9.1) (2.2.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk==3.6.2) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk==3.6.2) (1.0.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from nltk==3.6.2) (2019.12.20)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==3.1.0) (21.0)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers==3.1.0) (0.0.45)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==3.1.0) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==3.1.0) (3.0.12)
# Requirement already satisfied: sentencepiece!=0.1.92 in /usr/local/lib/python3.7/dist-packages (from transformers==3.1.0) (0.1.96)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim==3.8.3) (1.4.1)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from gensim==3.8.3) (1.15.0)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from gensim==3.8.3) (5.1.0)
# Requirement already satisfied: stringcase<2.0,>=1.2 in /usr/local/lib/python3.7/dist-packages (from cltk) (1.2.0)
# Requirement already satisfied: spacy<3.0.0,>=2.3.5 in /usr/local/lib/python3.7/dist-packages (from cltk) (2.3.7)
# Requirement already satisfied: scikit-learn<0.25.0,>=0.24.2 in /usr/local/lib/python3.7/dist-packages (from cltk) (0.24.2)
# Requirement already satisfied: gitpython<4.0,>=3.0 in /usr/local/lib/python3.7/dist-packages (from cltk) (3.1.18)
# Requirement already satisfied: greek-accentuation<2.0.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from cltk) (1.2.0)
# Requirement already satisfied: python-Levenshtein<0.13.0,>=0.12.0 in /usr/local/lib/python3.7/dist-packages (from cltk) (0.12.2)
# Requirement already satisfied: stanza==1.1.1 in /usr/local/lib/python3.7/dist-packages (from cltk) (1.1.1)
# Requirement already satisfied: boltons<21.0.0,>=20.0.0 in /usr/local/lib/python3.7/dist-packages (from cltk) (20.2.1)
# Requirement already satisfied: fasttext<0.10.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from cltk) (0.9.2)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from stanza==1.1.1->cltk) (1.9.0+cu102)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from stanza==1.1.1->cltk) (3.17.3)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from fasttext<0.10.0,>=0.9.1->cltk) (57.2.0)
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.7/dist-packages (from fasttext<0.10.0,>=0.9.1->cltk) (2.7.1)
# Requirement already satisfied: typing-extensions>=3.7.4.0 in /usr/local/lib/python3.7/dist-packages (from gitpython<4.0,>=3.0->cltk) (3.7.4.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from gitpython<4.0,>=3.0->cltk) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from gitdb<5,>=4.0.1->gitpython<4.0,>=3.0->cltk) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.1.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.1.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.1.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.1.0) (2021.5.30)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<0.25.0,>=0.24.2->cltk) (2.2.0)
# Requirement already satisfied: thinc<7.5.0,>=7.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.3.5->cltk) (7.4.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.3.5->cltk) (0.8.2)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.3.5->cltk) (1.1.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.3.5->cltk) (0.4.1)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.3.5->cltk) (1.0.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.3.5->cltk) (3.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.3.5->cltk) (1.0.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.3.5->cltk) (1.0.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.3.5->cltk) (2.0.5)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy<3.0.0,>=2.3.5->cltk) (4.6.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<3.0.0,>=2.3.5->cltk) (3.5.0)
# Requirement already satisfied: gevent in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (21.8.0)
# Requirement already satisfied: gin-config in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (0.4.0)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (1.12.8)
# Requirement already satisfied: gunicorn in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (20.1.0)
# Requirement already satisfied: flask in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (1.1.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (1.7.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (3.1.0)
# Requirement already satisfied: tensorflow-gan in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (2.0.0)
# Requirement already satisfied: pypng in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (0.0.20)
# Requirement already satisfied: dopamine-rl in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (1.0.5)
# Requirement already satisfied: kfac in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (0.2.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (7.1.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (4.1.2.30)
# Requirement already satisfied: bz2file in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (0.98)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (0.12.0)
# Requirement already satisfied: tf-slim in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (1.1.0)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (4.1.3)
# Requirement already satisfied: mesh-tensorflow in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (0.1.19)
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (0.13.0)
# Requirement already satisfied: tensorflow-probability==0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (0.7.0)
# Requirement already satisfied: gym in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (0.17.3)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (4.0.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from tensorflow-probability==0.7.0->tensor2tensor) (4.4.2)
# Requirement already satisfied: cloudpickle>=0.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-probability==0.7.0->tensor2tensor) (1.6.0)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym->tensor2tensor) (1.5.0)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from flask->tensor2tensor) (1.0.1)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from flask->tensor2tensor) (2.11.3)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from flask->tensor2tensor) (1.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->flask->tensor2tensor) (2.0.1)
# Requirement already satisfied: greenlet<2.0,>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from gevent->tensor2tensor) (1.1.1)
# Requirement already satisfied: zope.event in /usr/local/lib/python3.7/dist-packages (from gevent->tensor2tensor) (4.5.0)
# Requirement already satisfied: zope.interface in /usr/local/lib/python3.7/dist-packages (from gevent->tensor2tensor) (5.4.0)
# Requirement already satisfied: google-auth>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client->tensor2tensor) (1.34.0)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client->tensor2tensor) (3.0.1)
# Requirement already satisfied: google-api-core<2dev,>=1.21.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client->tensor2tensor) (1.26.3)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client->tensor2tensor) (0.17.4)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client->tensor2tensor) (0.0.4)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client->tensor2tensor) (1.53.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client->tensor2tensor) (2018.9)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.16.0->google-api-python-client->tensor2tensor) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.16.0->google-api-python-client->tensor2tensor) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.16.0->google-api-python-client->tensor2tensor) (4.7.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==3.1.0) (2.4.7)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.16.0->google-api-python-client->tensor2tensor) (0.4.8)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->tensor2tensor) (1.5.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.7/dist-packages (from sympy->tensor2tensor) (1.2.1)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons->tensor2tensor) (2.7.1)
# Requirement already satisfied: attrs>=18.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tensor2tensor) (21.2.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tensor2tensor) (2.3)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tensor2tensor) (1.1.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tensor2tensor) (0.3.4)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tensor2tensor) (1.2.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tensor2tensor) (0.1.6)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tensor2tensor) (5.2.2)
# Requirement already satisfied: tensorflow-hub>=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gan->tensor2tensor) (0.12.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (0.24.2)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.19.5)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.0.1)
# Requirement already satisfied: spacy in /usr/local/lib/python3.7/dist-packages (2.3.7)
# Collecting spacy
#   Using cached spacy-3.1.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.4 MB)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.19.5)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (21.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.11.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.8.2)
# Collecting thinc<8.1.0,>=8.0.8
#   Using cached thinc-8.0.8-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (621 kB)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.5)
# Collecting srsly<3.0.0,>=2.4.1
#   Using cached srsly-2.4.1-cp37-cp37m-manylinux2014_x86_64.whl (456 kB)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.23.0)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy) (57.2.0)
# Collecting catalogue<2.1.0,>=2.0.4
#   Using cached catalogue-2.0.5-py3-none-any.whl (17 kB)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.8.2)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.7.4.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (4.48.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.3.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.5)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.4->spacy) (3.5.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy) (5.1.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.4.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy) (2.0.1)
# Installing collected packages: catalogue, srsly, thinc, spacy
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 1.0.0
#     Uninstalling catalogue-1.0.0:
#       Successfully uninstalled catalogue-1.0.0
#   Attempting uninstall: srsly
#     Found existing installation: srsly 1.0.5
#     Uninstalling srsly-1.0.5:
#       Successfully uninstalled srsly-1.0.5
#   Attempting uninstall: thinc
#     Found existing installation: thinc 7.4.5
#     Uninstalling thinc-7.4.5:
#       Successfully uninstalled thinc-7.4.5
#   Attempting uninstall: spacy
#     Found existing installation: spacy 2.3.7
#     Uninstalling spacy-2.3.7:
#       Successfully uninstalled spacy-2.3.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cltk 1.0.16 requires spacy<3.0.0,>=2.3.5, but you have spacy 3.1.1 which is incompatible.
# Successfully installed catalogue-2.0.5 spacy-3.1.1 srsly-2.4.1 thinc-8.0.8
# Requirement already satisfied: spacy in /usr/local/lib/python3.7/dist-packages (3.1.1)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.3.2)
# Requirement already satisfied: thinc<8.1.0,>=8.0.8 in /usr/local/lib/python3.7/dist-packages (from spacy) (8.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.11.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.8.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.23.0)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.7.4.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy) (57.2.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (21.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (4.48.2)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.6.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.8.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.4.1)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.19.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.5)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.4->spacy) (3.5.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy) (5.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.4.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy) (2.0.1)
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.7/dist-packages (0.5.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from umap-learn) (1.19.5)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from umap-learn) (0.24.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.7/dist-packages (from umap-learn) (1.4.1)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.7/dist-packages (from umap-learn) (0.51.2)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.7/dist-packages (from umap-learn) (0.5.4)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn) (57.2.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from pynndescent>=0.5->umap-learn) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22->umap-learn) (2.2.0)
# Requirement already satisfied: umap-learn[plot] in /usr/local/lib/python3.7/dist-packages (0.5.1)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.7/dist-packages (from umap-learn[plot]) (0.5.4)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from umap-learn[plot]) (0.24.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from umap-learn[plot]) (1.19.5)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.7/dist-packages (from umap-learn[plot]) (0.51.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.7/dist-packages (from umap-learn[plot]) (1.4.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from umap-learn[plot]) (1.1.5)
# Requirement already satisfied: colorcet in /usr/local/lib/python3.7/dist-packages (from umap-learn[plot]) (2.0.6)
# Requirement already satisfied: holoviews in /usr/local/lib/python3.7/dist-packages (from umap-learn[plot]) (1.14.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from umap-learn[plot]) (3.2.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.7/dist-packages (from umap-learn[plot]) (0.16.2)
# Requirement already satisfied: bokeh in /usr/local/lib/python3.7/dist-packages (from umap-learn[plot]) (2.3.3)
# Requirement already satisfied: datashader in /usr/local/lib/python3.7/dist-packages (from umap-learn[plot]) (0.13.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.7/dist-packages (from umap-learn[plot]) (0.11.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn[plot]) (57.2.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn[plot]) (0.34.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from pynndescent>=0.5->umap-learn[plot]) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22->umap-learn[plot]) (2.2.0)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.7/dist-packages (from bokeh->umap-learn[plot]) (5.1.1)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.7/dist-packages (from bokeh->umap-learn[plot]) (5.4.1)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from bokeh->umap-learn[plot]) (2.8.2)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.7/dist-packages (from bokeh->umap-learn[plot]) (2.11.3)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.7/dist-packages (from bokeh->umap-learn[plot]) (7.1.2)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from bokeh->umap-learn[plot]) (3.7.4.3)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.7/dist-packages (from bokeh->umap-learn[plot]) (21.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2>=2.9->bokeh->umap-learn[plot]) (2.0.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=16.8->bokeh->umap-learn[plot]) (2.4.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.1->bokeh->umap-learn[plot]) (1.15.0)
# Requirement already satisfied: pyct>=0.4.4 in /usr/local/lib/python3.7/dist-packages (from colorcet->umap-learn[plot]) (0.4.8)
# Requirement already satisfied: param>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from colorcet->umap-learn[plot]) (1.11.1)
# Requirement already satisfied: dask[complete]>=0.18.0 in /usr/local/lib/python3.7/dist-packages (from datashader->umap-learn[plot]) (2.12.0)
# Requirement already satisfied: xarray>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from datashader->umap-learn[plot]) (0.18.2)
# Requirement already satisfied: datashape>=0.5.1 in /usr/local/lib/python3.7/dist-packages (from datashader->umap-learn[plot]) (0.5.2)
# Requirement already satisfied: toolz>=0.7.3 in /usr/local/lib/python3.7/dist-packages (from dask[complete]>=0.18.0->datashader->umap-learn[plot]) (0.11.1)
# Requirement already satisfied: cloudpickle>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from dask[complete]>=0.18.0->datashader->umap-learn[plot]) (1.6.0)
# Requirement already satisfied: distributed>=2.0 in /usr/local/lib/python3.7/dist-packages (from dask[complete]>=0.18.0->datashader->umap-learn[plot]) (2.30.1)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.7/dist-packages (from dask[complete]>=0.18.0->datashader->umap-learn[plot]) (1.2.0)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from dask[complete]>=0.18.0->datashader->umap-learn[plot]) (2021.7.0)
# Requirement already satisfied: multipledispatch>=0.4.7 in /usr/local/lib/python3.7/dist-packages (from datashape>=0.5.1->datashader->umap-learn[plot]) (0.6.0)
# Requirement already satisfied: psutil>=5.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.0->dask[complete]>=0.18.0->datashader->umap-learn[plot]) (5.4.8)
# Requirement already satisfied: click>=6.6 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.0->dask[complete]>=0.18.0->datashader->umap-learn[plot]) (7.1.2)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.0->dask[complete]>=0.18.0->datashader->umap-learn[plot]) (2.0.0)
# Requirement already satisfied: msgpack>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.0->dask[complete]>=0.18.0->datashader->umap-learn[plot]) (1.0.2)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.0->dask[complete]>=0.18.0->datashader->umap-learn[plot]) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.0->dask[complete]>=0.18.0->datashader->umap-learn[plot]) (1.7.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->umap-learn[plot]) (2018.9)
# Requirement already satisfied: locket in /usr/local/lib/python3.7/dist-packages (from partd>=0.3.10->dask[complete]>=0.18.0->datashader->umap-learn[plot]) (0.2.1)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.7/dist-packages (from zict>=0.1.3->distributed>=2.0->dask[complete]>=0.18.0->datashader->umap-learn[plot]) (1.0.1)
# Requirement already satisfied: panel>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from holoviews->umap-learn[plot]) (0.12.1)
# Requirement already satisfied: pyviz-comms>=0.7.4 in /usr/local/lib/python3.7/dist-packages (from holoviews->umap-learn[plot]) (2.1.0)
# Requirement already satisfied: tqdm>=4.48.0 in /usr/local/lib/python3.7/dist-packages (from panel>=0.8.0->holoviews->umap-learn[plot]) (4.48.2)
# Requirement already satisfied: markdown in /usr/local/lib/python3.7/dist-packages (from panel>=0.8.0->holoviews->umap-learn[plot]) (3.3.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from panel>=0.8.0->holoviews->umap-learn[plot]) (4.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from panel>=0.8.0->holoviews->umap-learn[plot]) (2.23.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->panel>=0.8.0->holoviews->umap-learn[plot]) (0.5.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown->panel>=0.8.0->holoviews->umap-learn[plot]) (4.6.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown->panel>=0.8.0->holoviews->umap-learn[plot]) (3.5.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->umap-learn[plot]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->umap-learn[plot]) (0.10.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->panel>=0.8.0->holoviews->umap-learn[plot]) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->panel>=0.8.0->holoviews->umap-learn[plot]) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->panel>=0.8.0->holoviews->umap-learn[plot]) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->panel>=0.8.0->holoviews->umap-learn[plot]) (1.24.3)
# Requirement already satisfied: PyWavelets>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->umap-learn[plot]) (1.1.1)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->umap-learn[plot]) (2.6.2)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->umap-learn[plot]) (2.4.1)

# %%
#Import the necessary libraries
import re
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn import metrics
import pandas as pd
#import cltk
#from cltk import embeddings
import sys
import os
import umap
import umap.plot
import numpy as np
import networkx as nx
syspath = 'LatinBERT/'
if syspath not in sys.path:
    sys.path.append(syspath)

from cltk.data.fetch import FetchCorpus
from cltk.tokenizers.lat.lat import LatinWordTokenizer as WordTokenizer
from cltk.sentence.lat import LatinPunktSentenceTokenizer as SentenceTokenizer
from cltk import NLP

corpus_downloader = FetchCorpus(language="lat")
corpus_downloader.list_corpora
corpus_downloader.import_corpus("lat_models_cltk")

cltk_nlp = NLP(language="lat")

from latbert import LatinBERT


tokenizerPath = 'LatinBERT/latin.subword.encoder'
bertPath = 'latin_bert/'
bert=LatinBERT(tokenizerPath=tokenizerPath, bertPath=bertPath)
# Out:
# ‎𐤀 CLTK version '1.0.16'.
# Pipeline for language 'Latin' (ISO: 'lat'): `LatinNormalizeProcess`, `LatinStanzaProcess`, `LatinEmbeddingsProcess`, `StopsProcess`, `LatinNERProcess`, `LatinLexiconProcess`.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-3a9b14ba2307> in <module>()
#      33 tokenizerPath = 'LatinBERT/latin.subword.encoder'
#      34 bertPath = 'latin_bert/'
# ---> 35 bert=LatinBERT(tokenizerPath=tokenizerPath, bertPath=bertPath)
#
# /content/LatinBERT/latbert.py in __init__(self, tokenizerPath, bertPath)
#      14
#      15         def __init__(self, tokenizerPath=None, bertPath=None):
# ---> 16                 encoder = text_encoder.SubwordTextEncoder(tokenizerPath)
#      17                 self.wp_tokenizer = LatinTokenizer(encoder)
#      18                 self.model = BertLatin(bertPath=bertPath)
#
# /usr/local/lib/python3.7/dist-packages/tensor2tensor/data_generators/text_encoder.py in __init__(self, filename)
#     489     self.filename = filename
#     490     if filename is not None:
# --> 491       self._load_from_file(filename)
#     492     super(SubwordTextEncoder, self).__init__()
#     493
#
# /usr/local/lib/python3.7/dist-packages/tensor2tensor/data_generators/text_encoder.py in _load_from_file(self, filename)
#     937     """Load from a vocab file."""
#     938     if not tf.gfile.Exists(filename):
# --> 939       raise ValueError("File %s not found" % filename)
#     940     with tf.gfile.Open(filename) as f:
#     941       self._load_from_file_object(f)
#
# ValueError: File LatinBERT/latin.subword.encoder not found

# %% [markdown]
# # NLP with Latin-Bert

# %%
df=pd.read_csv('prose_by_authors')    #read the dataset 
df=df.drop(labels=[6,7,10], axis=0)   #6,7,10 give problem, I delete them
df=df.sample(frac=1)
df=df.reset_index()
df
# Out:
#     index  ...                age
# 0      46  ...   4TH CENTURY A.D.
# 1      34  ...   4TH CENTURY A.D.
# 2      43  ...      C.40-103 A.D.
# 3       8  ...  63 B.C. – A.D. 14
# 4      41  ...      C.40-103 A.D.
# ..    ...  ...                ...
# 90     60  ...      63-C.113 A.D.
# 91     35  ...   4TH CENTURY A.D.
# 92     86  ...  C.56 - C.117 A.D.
# 93     94  ...        116-27 B.C.
# 94     17  ...   4th century A.D.
#
# [95 rows x 5 columns]

# %%
#preprocessing
docs=[] 
docs_labels=[]                           
for i in range(len(df)):
  t=re.sub(r'[^\w\s]', '', df['text'][i])
  t=t.lower()
  docs.append(re.sub(r'[0-9]+', '', t))
  docs_labels.append((re.sub(r'[0-9]+', '', t),df['label'][i]))

# %%
#preprocessing
docs=[] 
docs_labels=[]                           
for i in range(len(df)):
  #t=re.sub(r'[^\w\s]', '', df['text'][i])
  #t=t.lower()
  docs.append(df['text'][i])
  docs_labels.append((df['text'][i],df['label'][i]))

# %%
#documents embedding with latin bert
bert_sents=bert.get_berts(docs,docs_labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-f4917517cf87> in <module>()
#       1 #documents embedding with latin bert
# ----> 2 bert_sents=bert.get_berts(docs,docs_labels)
#
# NameError: name 'bert' is not defined

# %%
#at each document corresponds a vector
vec=[]
for i in range(len(bert_sents)):
  vec.append(bert_sents[i][0][1])
X=np.array(vec)
np.shape(X)
# Out:
# (95, 768)

# %%
y=np.array(df['label'])      #labels
auth=df['author']      #authors

# %% [markdown]
# # Cosine similarity

# %%
cos=pd.DataFrame(metrics.pairwise.cosine_similarity(X))
cos
# Out:
#           0         1         2   ...        92        93        94
# 0   1.000000  0.907141  0.922055  ...  0.756970  0.755018  0.719425
# 1   0.907141  1.000000  0.863017  ...  0.766948  0.744101  0.714693
# 2   0.922055  0.863017  1.000000  ...  0.769020  0.767356  0.739955
# 3   0.909177  0.901111  0.886971  ...  0.778970  0.779879  0.736768
# 4   0.838415  0.845610  0.846323  ...  0.781880  0.729675  0.659296
# ..       ...       ...       ...  ...       ...       ...       ...
# 90  0.839742  0.832638  0.840940  ...  0.774770  0.761353  0.731957
# 91  0.764144  0.723152  0.777610  ...  0.854394  0.905545  0.878681
# 92  0.756970  0.766948  0.769020  ...  1.000000  0.846353  0.802535
# 93  0.755018  0.744101  0.767356  ...  0.846353  1.000000  0.837206
# 94  0.719425  0.714693  0.739955  ...  0.802535  0.837206  1.000000
#
# [95 rows x 95 columns]

# %%
np.array(cos).min()
# Out:
# 0.59793377

# %%
from sklearn.preprocessing import MinMaxScaler
cos=MinMaxScaler().fit_transform(cos)

# %%
import seaborn as sns
#,xticklabels=ll
plt.figure(figsize=(22,20))
sns.heatmap(cos,vmin=0, vmax=1,xticklabels=auth,yticklabels=auth,cbar_kws={'label': 'cosine similarity'})

# %% [markdown]
# # Data visualization - UMAP

# %%
#dimensionality reduction with UMAP and graphical representation - plot 1
mapper = umap.UMAP(random_state=42, n_components=2, min_dist=0.99, metric='cosine', n_neighbors=2).fit(X)
umap.plot.points(mapper, labels=auth)

# %%
#dimensionality reduction with UMAP and graphical representation - plot 2, different parameters
mapper = umap.UMAP(random_state=42, n_components=2, metric='cosine',n_neighbors=4, min_dist=0.99).fit(vec)
umap.plot.points(mapper, labels=df['author'])

# %% [markdown]
# # Multiclass classification

# %%
#import the machine learning libraries
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cluster import KMeans
from sklearn.metrics.cluster import rand_score

# %% [markdown]
# ### Clustering with K-means

# %%
kmeans_labels = KMeans(random_state=0, n_clusters=23).fit_predict(X)  #mapper.transform(X)
kmeans_labels, y
# Out:
# (array([10,  5,  5,  2, 11, 19, 20, 13, 14, 10, 16, 20, 16, 20,  8, 19,  2,
#          2,  2, 22,  2,  8,  6, 20,  3, 20, 18, 10, 21, 13, 15, 10,  7, 20,
#          6, 17,  1,  9,  6, 12, 14,  4, 12,  5, 10, 21, 22,  0,  2,  1,  0,
#          6,  5, 14,  1, 11, 14,  1,  7,  9,  0,  2, 18, 14, 14,  8, 10,  1,
#         19,  6, 11,  6, 12, 20,  6, 21, 20, 13, 17, 14, 16, 11, 11, 16,  9,
#          2, 16,  7,  0, 12, 16, 10,  2, 12, 10], dtype=int32),
#  array([17,  1,  1, 20,  6,  7,  5, 23,  4,  5, 18,  7, 18, 15, 16, 10, 20,
#         19, 19, 23, 20, 16, 10, 22, 23, 15,  2, 13,  8, 16,  8, 17, 14, 15,
#          5,  3, 16, 21, 12,  9, 15, 14,  9,  1, 21,  8, 23, 12, 19, 13,  4,
#         11,  1,  7, 13, 22, 15, 13, 14, 21,  4, 20,  2, 15,  7, 16, 17, 13,
#         11, 10, 22, 12,  9, 12, 10,  8, 15,  6,  3,  7, 18, 22, 22, 18, 21,
#         19, 18, 14,  4,  9, 18, 17, 20,  9, 17]))

# %%
rand_score(kmeans_labels,y)
# Out:
# 0.9612541993281075

# %% [markdown]
# ### Model selection - supervised

# %%
clf = OneVsRestClassifier(SVC())
scores = cross_val_score(clf, X, y, cv=5)
scores, np.mean(scores)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:668: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# (array([0.84210526, 0.68421053, 0.84210526, 0.78947368, 0.84210526]), 0.8)

# %%
clf = OneVsRestClassifier(MLPClassifier(random_state=1, max_iter=300, activation='relu'))
scores = cross_val_score(clf, X, y, cv=5)
scores, np.mean(scores)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:668: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# (array([0.89473684, 0.84210526, 0.78947368, 0.73684211, 0.89473684]),
#  0.8315789473684211)

# %%
clf = KNeighborsClassifier(n_neighbors=1)
scores = cross_val_score(clf, X, y, cv=5)
scores, np.mean(scores)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:668: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# (array([0.68421053, 0.78947368, 0.89473684, 0.78947368, 0.84210526]), 0.8)

# %% [markdown]
# ### Compute the probability of belonging to a certain class

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=10)

# %%
pref = KNeighborsClassifier(n_neighbors=1).fit(X_train, y_train)

# %%
pref = OneVsRestClassifier(MLPClassifier(random_state=1, max_iter=300, activation='relu')).fit(X_train, y_train)

# %%
pref.score(X_test, y_test)
# Out:
# 0.8421052631578947

# %%
prob=pref.predict_proba(X_test)

# %%
plt.imshow(prob)

# %% [markdown]
# # Network of authors

# %%
#we consider the k_means centers
kmeans = KMeans(n_clusters=23, random_state=0).fit(X)
cen=kmeans.cluster_centers_
np.shape(cen)
cos=pd.DataFrame(metrics.pairwise.cosine_similarity(cen))
plt.imshow(cos.to_numpy())

# %%
#rescale
cos=scaler.fit_transform(cos)
cos=MinMaxScaler().fit_transform(cos)
plt.imshow(cos)

# %%
plt.hist(np.reshape(cos,(len(cos)**2,1)),bins=40)
# Out:
# (array([29., 11.,  4., 12.,  7., 12., 19., 15., 36., 18., 27., 33., 27.,
#         34., 34., 18., 16., 20., 17., 19.,  8., 17., 15.,  4.,  8., 16.,
#          8.,  8.,  6.,  3.,  2.,  3.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,
#         23.]),
#  array([0.   , 0.025, 0.05 , 0.075, 0.1  , 0.125, 0.15 , 0.175, 0.2  ,
#         0.225, 0.25 , 0.275, 0.3  , 0.325, 0.35 , 0.375, 0.4  , 0.425,
#         0.45 , 0.475, 0.5  , 0.525, 0.55 , 0.575, 0.6  , 0.625, 0.65 ,
#         0.675, 0.7  , 0.725, 0.75 , 0.775, 0.8  , 0.825, 0.85 , 0.875,
#         0.9  , 0.925, 0.95 , 0.975, 1.   ], dtype=float32),
#  <a list of 40 Patch objects>)

# %%
#dimensionality reduction with UMAP and graphical representation - plot 1
mapper = umap.UMAP(random_state=42, n_components=2, min_dist=0.9, metric='euclidean', n_neighbors=3).fit(cen)
#position - the same as umap
p=mapper.transform(cen)
#plot
umap.plot.points(mapper, labels=np.array(list(auth_unique)))

# %%
li=[]
col=[]

N=np.shape(cos)[0]

for i in range(N):
    for j in range(N):
      if cos[i][j]!=0:
        li.append([i,j,cos[i][j]])

for i in range(len(li)):
    col.append(li[i][2])

G1 = nx.DiGraph() 
G1.add_weighted_edges_from(li)

# %%
#Plotting network with colormap based on cosine similarity
plt.figure(figsize=(12, 13))

vmin = np.min(np.array(cos))
vmax = np.max(np.array(cos))

edge=nx.draw_networkx_edges(G1, p, alpha=0.8, edge_color=col, width=0.2,  edge_vmin=vmin, edge_vmax=vmax, edge_cmap=plt.cm.cool) 

nx.draw_networkx_nodes(G1, p, node_size=50.0, node_color=range(len(auth_unique)), alpha=0.8)  


sm = plt.cm.ScalarMappable(cmap=plt.cm.cool) #, norm=plt.Normalize(vmin=vmin, vmax=vmax)
sm.set_array([])
cbar = plt.colorbar(sm,shrink=0.65, label="cosine similarity")

plt.scatter(p[:,0], p[:,1])
n=auth_unique
for i, txt in enumerate(n):
    plt.annotate(txt, (p[i,0], p[i,1]))

plt.axis('off')
plt.show()

# %%
cos[cos < .4] = 0
li=[]
col=[]

N=np.shape(cos)[0]

for i in range(N):
    for j in range(N):
      if cos[i][j]!=0:
        li.append([i,j,cos[i][j]])

for i in range(len(li)):
    col.append(li[i][2])

G1 = nx.DiGraph() 
G1.add_weighted_edges_from(li)

#Plotting network with colormap based on cosine similarity
plt.figure(figsize=(12, 13))

vmin = np.min(np.array(cos))
vmax = np.max(np.array(cos))

edge=nx.draw_networkx_edges(G1, p, alpha=0.8, edge_color=col, width=0.2,  edge_vmin=vmin, edge_vmax=vmax, edge_cmap=plt.cm.cool) 

nx.draw_networkx_nodes(G1, p, node_size=50.0, node_color=range(len(auth_unique)), alpha=0.8)  


sm = plt.cm.ScalarMappable(cmap=plt.cm.cool) #, norm=plt.Normalize(vmin=vmin, vmax=vmax)
sm.set_array([])
cbar = plt.colorbar(sm,shrink=0.65, label="cosine similarity")

plt.scatter(p[:,0], p[:,1])
n=auth_unique
for i, txt in enumerate(n):
    plt.annotate(txt, (p[i,0], p[i,1]))

plt.axis('off')
plt.show()

# %%
from sklearn.metrics.pairwise import euclidean_distances
eu=euclidean_distances(cen,cen)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
dis=1-scaler.fit_transform(eu)
dis.mean()
# Out:
# 0.24308583
