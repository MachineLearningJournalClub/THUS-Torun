# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1Jhg9uWixFmLSzLE-6MzWvMRASQWPaZXQ?usp=sharing)

# %%
# !wget --no-check-certificate --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1Te_14UB-DZ8wYPhHGyDg7LadDTjNzpti' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1Te_14UB-DZ8wYPhHGyDg7LadDTjNzpti" -O latin_bert.tar && rm -f /tmp/cookies.txt
# !tar -xf latin_bert.tar
# Out:
# --2021-08-16 19:50:33--  https://docs.google.com/uc?export=download&confirm=K3Ye&id=1Te_14UB-DZ8wYPhHGyDg7LadDTjNzpti
# Resolving docs.google.com (docs.google.com)... 142.251.2.113, 142.251.2.101, 142.251.2.102, ...
# Connecting to docs.google.com (docs.google.com)|142.251.2.113|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-08-4k-docs.googleusercontent.com/docs/securesc/6plceu8gholfna9cfpqsd06hsdcg0ftm/5ec3qh5j10ghucasddehuraspjutmonh/1629143400000/09859182337762586004/14927945015189594106Z/1Te_14UB-DZ8wYPhHGyDg7LadDTjNzpti?e=download [following]
# --2021-08-16 19:50:33--  https://doc-08-4k-docs.googleusercontent.com/docs/securesc/6plceu8gholfna9cfpqsd06hsdcg0ftm/5ec3qh5j10ghucasddehuraspjutmonh/1629143400000/09859182337762586004/14927945015189594106Z/1Te_14UB-DZ8wYPhHGyDg7LadDTjNzpti?e=download
# Resolving doc-08-4k-docs.googleusercontent.com (doc-08-4k-docs.googleusercontent.com)... 142.251.2.132, 2607:f8b0:4023:c0d::84
# Connecting to doc-08-4k-docs.googleusercontent.com (doc-08-4k-docs.googleusercontent.com)|142.251.2.132|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://docs.google.com/nonceSigner?nonce=uvok8cs8da8gc&continue=https://doc-08-4k-docs.googleusercontent.com/docs/securesc/6plceu8gholfna9cfpqsd06hsdcg0ftm/5ec3qh5j10ghucasddehuraspjutmonh/1629143400000/09859182337762586004/14927945015189594106Z/1Te_14UB-DZ8wYPhHGyDg7LadDTjNzpti?e%3Ddownload&hash=2cqstblpiucr7p6cno2u0dbal9uefipe [following]
# --2021-08-16 19:50:33--  https://docs.google.com/nonceSigner?nonce=uvok8cs8da8gc&continue=https://doc-08-4k-docs.googleusercontent.com/docs/securesc/6plceu8gholfna9cfpqsd06hsdcg0ftm/5ec3qh5j10ghucasddehuraspjutmonh/1629143400000/09859182337762586004/14927945015189594106Z/1Te_14UB-DZ8wYPhHGyDg7LadDTjNzpti?e%3Ddownload&hash=2cqstblpiucr7p6cno2u0dbal9uefipe
# Connecting to docs.google.com (docs.google.com)|142.251.2.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://doc-08-4k-docs.googleusercontent.com/docs/securesc/6plceu8gholfna9cfpqsd06hsdcg0ftm/5ec3qh5j10ghucasddehuraspjutmonh/1629143400000/09859182337762586004/14927945015189594106Z/1Te_14UB-DZ8wYPhHGyDg7LadDTjNzpti?e=download&nonce=uvok8cs8da8gc&user=14927945015189594106Z&hash=j1roklpitb5sdecl20c1jksad1ja6aia [following]
# --2021-08-16 19:50:34--  https://doc-08-4k-docs.googleusercontent.com/docs/securesc/6plceu8gholfna9cfpqsd06hsdcg0ftm/5ec3qh5j10ghucasddehuraspjutmonh/1629143400000/09859182337762586004/14927945015189594106Z/1Te_14UB-DZ8wYPhHGyDg7LadDTjNzpti?e=download&nonce=uvok8cs8da8gc&user=14927945015189594106Z&hash=j1roklpitb5sdecl20c1jksad1ja6aia
# Connecting to doc-08-4k-docs.googleusercontent.com (doc-08-4k-docs.googleusercontent.com)|142.251.2.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/x-tar]
# Saving to: ‘latin_bert.tar’
#
# latin_bert.tar          [   <=>              ] 427.27M  59.0MB/s    in 9.2s
#
# 2021-08-16 19:50:43 (46.2 MB/s) - ‘latin_bert.tar’ saved [448020480]

# %%
# !git clone https://github.com/pietro-sillano/LatinBERT LatinBERT
# Out:
# Cloning into 'LatinBERT'...
# remote: Enumerating objects: 3344, done.
# remote: Counting objects: 100% (423/423), done.
# remote: Compressing objects: 100% (327/327), done.
# remote: Total 3344 (delta 100), reused 412 (delta 89), pack-reused 2921
# Receiving objects: 100% (3344/3344), 407.25 MiB | 34.78 MiB/s, done.
# Resolving deltas: 100% (170/170), done.
# Checking out files: 100% (3762/3762), done.

# %%
# !pip3 install  gast==0.4.0 cloudpickle==1.2.0 tensorflow-probability==0.7.0
# !pip3 install  tensor2tensor transformers==3.1.0 
# !pip3 install umap-learn
# !pip3 install --upgrade PyYAML
# !pip3 install --upgrade gensim==3.8.1
# !pip3 install --upgrade scikit-learn==0.24.2

# !pip3 install  cltk
# Out:
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (0.4.0)
# Collecting cloudpickle==1.2.0
#   Downloading cloudpickle-1.2.0-py2.py3-none-any.whl (24 kB)
# Collecting tensorflow-probability==0.7.0
#   Downloading tensorflow_probability-0.7.0-py2.py3-none-any.whl (981 kB)
#      |████████████████████████████████| 981 kB 9.1 MB/s
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from tensorflow-probability==0.7.0) (4.4.2)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-probability==0.7.0) (1.15.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow-probability==0.7.0) (1.19.5)
# Installing collected packages: cloudpickle, tensorflow-probability
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 1.3.0
#     Uninstalling cloudpickle-1.3.0:
#       Successfully uninstalled cloudpickle-1.3.0
#   Attempting uninstall: tensorflow-probability
#     Found existing installation: tensorflow-probability 0.13.0
#     Uninstalling tensorflow-probability-0.13.0:
#       Successfully uninstalled tensorflow-probability-0.13.0
# Successfully installed cloudpickle-1.2.0 tensorflow-probability-0.7.0
# Collecting tensor2tensor
#   Downloading tensor2tensor-1.15.7-py2.py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 8.2 MB/s
# Collecting transformers==3.1.0
#   Downloading transformers-3.1.0-py3-none-any.whl (884 kB)
#      |████████████████████████████████| 884 kB 58.1 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==3.1.0) (3.0.12)
# Collecting tokenizers==0.8.1.rc2
#   Downloading tokenizers-0.8.1rc2-cp37-cp37m-manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 65.9 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==3.1.0) (4.62.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==3.1.0) (2.23.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.45-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 59.4 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==3.1.0) (2019.12.20)
# Collecting sentencepiece!=0.1.92
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 52.6 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from transformers==3.1.0) (1.19.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==3.1.0) (21.0)
# Collecting tf-slim
#   Downloading tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
#      |████████████████████████████████| 352 kB 50.9 MB/s
# Requirement already satisfied: gin-config in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (0.4.0)
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.13.0-cp37-cp37m-manylinux2010_x86_64.whl (679 kB)
#      |████████████████████████████████| 679 kB 54.2 MB/s
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (3.1.0)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (4.0.1)
# Collecting gevent
#   Downloading gevent-21.8.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 1.3 MB/s
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (0.16.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (7.1.2)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (4.1.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (1.15.0)
# Collecting gunicorn
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 10.9 MB/s
# Requirement already satisfied: gym in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (0.17.3)
# Collecting pypng
#   Downloading pypng-0.0.20.tar.gz (649 kB)
#      |████████████████████████████████| 649 kB 54.2 MB/s
# Collecting bz2file
#   Downloading bz2file-0.98.tar.gz (11 kB)
# Requirement already satisfied: tensorflow-probability==0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (0.7.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (1.4.1)
# Collecting kfac
#   Downloading kfac-0.2.3-py2.py3-none-any.whl (191 kB)
#      |████████████████████████████████| 191 kB 60.1 MB/s
# Collecting tensorflow-gan
#   Downloading tensorflow_gan-2.0.0-py2.py3-none-any.whl (365 kB)
#      |████████████████████████████████| 365 kB 53.8 MB/s
# Collecting mesh-tensorflow
#   Downloading mesh_tensorflow-0.1.19-py3-none-any.whl (366 kB)
#      |████████████████████████████████| 366 kB 53.2 MB/s
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (1.12.8)
# Requirement already satisfied: sympy in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (1.7.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (4.1.2.30)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (0.12.0)
# Requirement already satisfied: flask in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (1.1.4)
# Requirement already satisfied: dopamine-rl in /usr/local/lib/python3.7/dist-packages (from tensor2tensor) (1.0.5)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from tensorflow-probability==0.7.0->tensor2tensor) (4.4.2)
# Requirement already satisfied: cloudpickle>=0.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-probability==0.7.0->tensor2tensor) (1.2.0)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym->tensor2tensor) (1.5.0)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from flask->tensor2tensor) (1.0.1)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from flask->tensor2tensor) (1.1.0)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from flask->tensor2tensor) (2.11.3)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from flask->tensor2tensor) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->flask->tensor2tensor) (2.0.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from gevent->tensor2tensor) (57.4.0)
# Collecting zope.interface
#   Downloading zope.interface-5.4.0-cp37-cp37m-manylinux2010_x86_64.whl (251 kB)
#      |████████████████████████████████| 251 kB 71.6 MB/s
# Requirement already satisfied: greenlet<2.0,>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from gevent->tensor2tensor) (1.1.1)
# Collecting zope.event
#   Downloading zope.event-4.5.0-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client->tensor2tensor) (3.0.1)
# Requirement already satisfied: google-api-core<2dev,>=1.21.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client->tensor2tensor) (1.26.3)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client->tensor2tensor) (0.0.4)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client->tensor2tensor) (0.17.4)
# Requirement already satisfied: google-auth>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client->tensor2tensor) (1.34.0)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client->tensor2tensor) (3.17.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client->tensor2tensor) (2018.9)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client->tensor2tensor) (1.53.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.16.0->google-api-python-client->tensor2tensor) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.16.0->google-api-python-client->tensor2tensor) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.16.0->google-api-python-client->tensor2tensor) (4.2.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==3.1.0) (2.4.7)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.16.0->google-api-python-client->tensor2tensor) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.1.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.1.0) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.1.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.1.0) (2021.5.30)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->tensor2tensor) (1.5.2)
# Collecting kfac
#   Downloading kfac-0.2.2-py2.py3-none-any.whl (191 kB)
#      |████████████████████████████████| 191 kB 62.6 MB/s
#   Downloading kfac-0.2.0-py2.py3-none-any.whl (178 kB)
#      |████████████████████████████████| 178 kB 76.2 MB/s
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.1.0) (1.0.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.7/dist-packages (from sympy->tensor2tensor) (1.2.1)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons->tensor2tensor) (2.7.1)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tensor2tensor) (1.1.0)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tensor2tensor) (1.2.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tensor2tensor) (0.1.6)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tensor2tensor) (0.3.4)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tensor2tensor) (5.2.2)
# Requirement already satisfied: attrs>=18.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tensor2tensor) (21.2.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tensor2tensor) (2.3)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources->tensorflow-datasets->tensor2tensor) (3.5.0)
# Requirement already satisfied: tensorflow-hub>=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-gan->tensor2tensor) (0.12.0)
# Building wheels for collected packages: bz2file, pypng
#   Building wheel for bz2file (setup.py) ... done
#   Created wheel for bz2file: filename=bz2file-0.98-py3-none-any.whl size=6883 sha256=8b22e222df7dfdfbed6516d25abb581c1d84751f0990aa5e8fb363670d86d05d
#   Stored in directory: /root/.cache/pip/wheels/85/ce/8d/b5f76b602b16a8a39f2ded74189cf5f09fc4a87bea16c54a8b
#   Building wheel for pypng (setup.py) ... done
#   Created wheel for pypng: filename=pypng-0.0.20-py3-none-any.whl size=67179 sha256=0818e576b636ff5736fd99d9870a4bc9a62ddbbcee62d7b85127f33863f04800
#   Stored in directory: /root/.cache/pip/wheels/54/64/43/dfd10cf95dc1687dc5350e861321ecd9a5d76b7c3d96fa1dc6
# Successfully built bz2file pypng
# Installing collected packages: zope.interface, zope.event, tokenizers, tf-slim, tensorflow-gan, tensorflow-addons, sentencepiece, sacremoses, pypng, mesh-tensorflow, kfac, gunicorn, gevent, bz2file, transformers, tensor2tensor
# Successfully installed bz2file-0.98 gevent-21.8.0 gunicorn-20.1.0 kfac-0.2.0 mesh-tensorflow-0.1.19 pypng-0.0.20 sacremoses-0.0.45 sentencepiece-0.1.96 tensor2tensor-1.15.7 tensorflow-addons-0.13.0 tensorflow-gan-2.0.0 tf-slim-1.1.0 tokenizers-0.8.1rc2 transformers-3.1.0 zope.event-4.5.0 zope.interface-5.4.0
# Collecting umap-learn
#   Downloading umap-learn-0.5.1.tar.gz (80 kB)
#      |████████████████████████████████| 80 kB 5.3 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from umap-learn) (1.19.5)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from umap-learn) (0.22.2.post1)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.7/dist-packages (from umap-learn) (1.4.1)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.7/dist-packages (from umap-learn) (0.51.2)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.4.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 17.7 MB/s
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn) (57.4.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from pynndescent>=0.5->umap-learn) (1.0.1)
# Building wheels for collected packages: umap-learn, pynndescent
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.1-py3-none-any.whl size=76564 sha256=55891df583271ad5df2a03a604586345117ffd00190c4a0ef980e323de4bb18b
#   Stored in directory: /root/.cache/pip/wheels/01/e7/bb/347dc0e510803d7116a13d592b10cc68262da56a8eec4dd72f
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.4-py3-none-any.whl size=52373 sha256=c4914f9e2722b6623804fccf62d8208a849e714ad1fd7a6d02e115174d61e364
#   Stored in directory: /root/.cache/pip/wheels/d0/5b/62/3401692ddad12324249c774c4b15ccb046946021e2b581c043
# Successfully built umap-learn pynndescent
# Installing collected packages: pynndescent, umap-learn
# Successfully installed pynndescent-0.5.4 umap-learn-0.5.1
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (3.13)
# Collecting PyYAML
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 6.5 MB/s
# Installing collected packages: PyYAML
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed PyYAML-5.4.1
# Collecting gensim==3.8.1
#   Downloading gensim-3.8.1-cp37-cp37m-manylinux1_x86_64.whl (24.2 MB)
#      |████████████████████████████████| 24.2 MB 78 kB/s
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim==3.8.1) (1.4.1)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from gensim==3.8.1) (1.15.0)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from gensim==3.8.1) (5.1.0)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.7/dist-packages (from gensim==3.8.1) (1.19.5)
# Installing collected packages: gensim
#   Attempting uninstall: gensim
#     Found existing installation: gensim 3.6.0
#     Uninstalling gensim-3.6.0:
#       Successfully uninstalled gensim-3.6.0
# Successfully installed gensim-3.8.1
# Collecting scikit-learn==0.24.2
#   Downloading scikit_learn-0.24.2-cp37-cp37m-manylinux2010_x86_64.whl (22.3 MB)
#      |████████████████████████████████| 22.3 MB 28 kB/s
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.24.2) (1.0.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.24.2) (1.19.5)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-2.2.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-learn==0.24.2) (1.4.1)
# Installing collected packages: threadpoolctl, scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.22.2.post1
#     Uninstalling scikit-learn-0.22.2.post1:
#       Successfully uninstalled scikit-learn-0.22.2.post1
# Successfully installed scikit-learn-0.24.2 threadpoolctl-2.2.0
# Collecting cltk
#   Downloading cltk-1.0.17-py3-none-any.whl (836 kB)
#      |████████████████████████████████| 836 kB 7.2 MB/s
# Collecting fasttext<0.10.0,>=0.9.1
#   Downloading fasttext-0.9.2.tar.gz (68 kB)
#      |████████████████████████████████| 68 kB 8.9 MB/s
# Requirement already satisfied: requests<3.0.0,>=2.22.0 in /usr/local/lib/python3.7/dist-packages (from cltk) (2.23.0)
# Collecting boltons<21.0.0,>=20.0.0
#   Downloading boltons-20.2.1-py2.py3-none-any.whl (170 kB)
#      |████████████████████████████████| 170 kB 69.5 MB/s
# Collecting gitpython<4.0,>=3.0
#   Downloading GitPython-3.1.18-py3-none-any.whl (170 kB)
#      |████████████████████████████████| 170 kB 69.7 MB/s
# Requirement already satisfied: gensim<4.0.0,>=3.8.1 in /usr/local/lib/python3.7/dist-packages (from cltk) (3.8.1)
# Collecting stanza==1.1.1
#   Downloading stanza-1.1.1-py3-none-any.whl (227 kB)
#      |████████████████████████████████| 227 kB 71.3 MB/s
# Requirement already satisfied: PyYAML<6.0.0,>=5.4.1 in /usr/local/lib/python3.7/dist-packages (from cltk) (5.4.1)
# Collecting nltk<4.0,>=3.5
#   Downloading nltk-3.6.2-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 47.3 MB/s
# Collecting python-Levenshtein<0.13.0,>=0.12.0
#   Downloading python-Levenshtein-0.12.2.tar.gz (50 kB)
#      |████████████████████████████████| 50 kB 9.5 MB/s
# Requirement already satisfied: tqdm<5.0.0,>=4.41.1 in /usr/local/lib/python3.7/dist-packages (from cltk) (4.62.0)
# Collecting greek-accentuation<2.0.0,>=1.2.0
#   Downloading greek_accentuation-1.2.0-py2.py3-none-any.whl (6.8 kB)
# Collecting spacy<3.0.0,>=2.3.5
#   Downloading spacy-2.3.7-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.4 MB)
#      |████████████████████████████████| 10.4 MB 9.8 MB/s
# Requirement already satisfied: scikit-learn<0.25.0,>=0.24.2 in /usr/local/lib/python3.7/dist-packages (from cltk) (0.24.2)
# Collecting stringcase<2.0,>=1.2
#   Downloading stringcase-1.2.0.tar.gz (3.0 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from stanza==1.1.1->cltk) (1.19.5)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from stanza==1.1.1->cltk) (3.17.3)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from stanza==1.1.1->cltk) (1.9.0+cu102)
# Collecting pybind11>=2.2
#   Using cached pybind11-2.7.1-py2.py3-none-any.whl (200 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from fasttext<0.10.0,>=0.9.1->cltk) (57.4.0)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim<4.0.0,>=3.8.1->cltk) (1.4.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from gensim<4.0.0,>=3.8.1->cltk) (5.1.0)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from gensim<4.0.0,>=3.8.1->cltk) (1.15.0)
# Requirement already satisfied: typing-extensions>=3.7.4.0 in /usr/local/lib/python3.7/dist-packages (from gitpython<4.0,>=3.0->cltk) (3.7.4.3)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.7-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.3 MB/s
# Collecting smmap<5,>=3.0.1
#   Downloading smmap-4.0.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from nltk<4.0,>=3.5->cltk) (2019.12.20)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk<4.0,>=3.5->cltk) (1.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk<4.0,>=3.5->cltk) (7.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.22.0->cltk) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.22.0->cltk) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.22.0->cltk) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.22.0->cltk) (1.24.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<0.25.0,>=0.24.2->cltk) (2.2.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.3.5->cltk) (2.0.5)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.3.5->cltk) (0.4.1)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.3.5->cltk) (1.0.0)
# Collecting thinc<7.5.0,>=7.4.1
#   Downloading thinc-7.4.5-cp37-cp37m-manylinux2014_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 56.8 MB/s
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.3.5->cltk) (3.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.3.5->cltk) (1.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.3.5->cltk) (0.8.2)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.3.5->cltk) (1.0.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.0.0,>=2.3.5->cltk) (1.1.3)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy<3.0.0,>=2.3.5->cltk) (4.6.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<3.0.0,>=2.3.5->cltk) (3.5.0)
# Building wheels for collected packages: fasttext, python-Levenshtein, stringcase
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp37-cp37m-linux_x86_64.whl size=3096993 sha256=e84f69f9173e745d6a64de202578f702ebccf8fb2a1a74b60a2d24a16ed75cf4
#   Stored in directory: /root/.cache/pip/wheels/4e/ca/bf/b020d2be95f7641801a6597a29c8f4f19e38f9c02a345bab9b
#   Building wheel for python-Levenshtein (setup.py) ... done
#   Created wheel for python-Levenshtein: filename=python_Levenshtein-0.12.2-cp37-cp37m-linux_x86_64.whl size=149874 sha256=b70ddbb60025c701c28e2a800d1a630e08d4ea060667aebbac6f6bcb163c8d67
#   Stored in directory: /root/.cache/pip/wheels/05/5f/ca/7c4367734892581bb5ff896f15027a932c551080b2abd3e00d
#   Building wheel for stringcase (setup.py) ... done
#   Created wheel for stringcase: filename=stringcase-1.2.0-py3-none-any.whl size=3587 sha256=68f852dd2ae2d2b6d215287687915bd19c2f42b8a1a2a3295cf6adc1f3994605
#   Stored in directory: /root/.cache/pip/wheels/86/ab/a3/a8fa7e0a07e80f547e03468c03827f8257f7339327986faed1
# Successfully built fasttext python-Levenshtein stringcase
# Installing collected packages: smmap, thinc, pybind11, gitdb, stringcase, stanza, spacy, python-Levenshtein, nltk, greek-accentuation, gitpython, fasttext, boltons, cltk
#   Attempting uninstall: thinc
#     Found existing installation: thinc 7.4.0
#     Uninstalling thinc-7.4.0:
#       Successfully uninstalled thinc-7.4.0
#   Attempting uninstall: spacy
#     Found existing installation: spacy 2.2.4
#     Uninstalling spacy-2.2.4:
#       Successfully uninstalled spacy-2.2.4
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.2.5
#     Uninstalling nltk-3.2.5:
#       Successfully uninstalled nltk-3.2.5
# Successfully installed boltons-20.2.1 cltk-1.0.17 fasttext-0.9.2 gitdb-4.0.7 gitpython-3.1.18 greek-accentuation-1.2.0 nltk-3.6.2 pybind11-2.7.1 python-Levenshtein-0.12.2 smmap-4.0.0 spacy-2.3.7 stanza-1.1.1 stringcase-1.2.0 thinc-7.4.5

# %%
import sys
import os
import matplotlib.pyplot as plt
import umap 
import numpy as np
import pandas as pd

from cltk.data.fetch import FetchCorpus
from cltk.tokenizers.lat.lat import LatinWordTokenizer as WordTokenizer
from cltk.sentence.lat import LatinPunktSentenceTokenizer as SentenceTokenizer
from cltk import NLP

corpus_downloader = FetchCorpus(language="lat")
corpus_downloader.import_corpus("lat_models_cltk")

cltk_nlp = NLP(language="lat")
# Out:
# ‎𐤀 CLTK version '1.0.17'.
# Pipeline for language 'Latin' (ISO: 'lat'): `LatinNormalizeProcess`, `LatinStanzaProcess`, `LatinEmbeddingsProcess`, `StopsProcess`, `LatinNERProcess`, `LatinLexiconProcess`.

# %%
# !cd LatinBERT/ && git pull
# Out:
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0
# Unpacking objects: 100% (3/3), done.
# From https://github.com/pietro-sillano/LatinBERT
#    70c58ac..8f4933b  main       -> origin/main
# Updating 70c58ac..8f4933b
# Fast-forward
#  script_generator_colab.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !python3 LatinBERT/script_generator_colab.py -b latin_bert -t LatinBERT -i LatinBERT/library_super_reduced -o pickle

# %%
# !bash script.sh
# Out:
#   1  su  9
# 2021-08-16 20:05:04.315039: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
# ++++++STARTING:  LatinBERT/library_super_reduced/plautus/plautus_vidularia.txt
# 3
#
#  batch num:  0 size of:  32
#
#  batch num:  1 size of:  32
#
#  batch num:  2 size of:  23
# ++++++ FINISHED LatinBERT/library_super_reduced/plautus/plautus_vidularia.txt +++++++++
#   2  su  9
# 2021-08-16 20:05:16.632666: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
# ++++++STARTING:  LatinBERT/library_super_reduced/plautus/plautus_amphitruo.txt
# 33
#
#  batch num:  0 size of:  32
#
#  batch num:  1 size of:  32
#
#  batch num:  2 size of:  32
#
#  batch num:  3 size of:  32
#
#  batch num:  4 size of:  32
#
#  batch num:  5 size of:  32
#
#  batch num:  6 size of:  32
#
#  batch num:  7 size of:  32
#
#  batch num:  8 size of:  32
#
#  batch num:  9 size of:  32
#
#  batch num:  10 size of:  32
#
#  batch num:  11 size of:  32
#
#  batch num:  12 size of:  32
#
#  batch num:  13 size of:  32
#
#  batch num:  14 size of:  32
#
#  batch num:  15 size of:  32
#
#  batch num:  16 size of:  32
#
#  batch num:  17 size of:  32
#
#  batch num:  18 size of:  32
#
#  batch num:  19 size of:  32
#
#  batch num:  20 size of:  32
#
#  batch num:  21 size of:  32
#
#  batch num:  22 size of:  32
#
#  batch num:  23 size of:  32
#
#  batch num:  24 size of:  32
#
#  batch num:  25 size of:  32
#
#  batch num:  26 size of:  32
#
#  batch num:  27 size of:  32
#
#  batch num:  28 size of:  32
#
#  batch num:  29 size of:  32
#
#  batch num:  30 size of:  32
#
#  batch num:  31 size of:  32
#
#  batch num:  32 size of:  12
# ++++++ FINISHED LatinBERT/library_super_reduced/plautus/plautus_amphitruo.txt +++++++++
#   3  su  9
# 2021-08-16 20:05:30.233068: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
# ++++++STARTING:  LatinBERT/library_super_reduced/plautus/plautus_stichus.txt
# 27
#
#  batch num:  0 size of:  32
#
#  batch num:  1 size of:  32
#
#  batch num:  2 size of:  32
#
#  batch num:  3 size of:  32
#
#  batch num:  4 size of:  32
#
#  batch num:  5 size of:  32
#
#  batch num:  6 size of:  32
#
#  batch num:  7 size of:  32
#
#  batch num:  8 size of:  32
#
#  batch num:  9 size of:  32
#
#  batch num:  10 size of:  32
#
#  batch num:  11 size of:  32
#
#  batch num:  12 size of:  32
#
#  batch num:  13 size of:  32
#
#  batch num:  14 size of:  32
#
#  batch num:  15 size of:  32
#
#  batch num:  16 size of:  32
#
#  batch num:  17 size of:  32
#
#  batch num:  18 size of:  32
#
#  batch num:  19 size of:  32
#
#  batch num:  20 size of:  32
#
#  batch num:  21 size of:  32
#
#  batch num:  22 size of:  32
#
#  batch num:  23 size of:  32
#
#  batch num:  24 size of:  32
#
#  batch num:  25 size of:  32
#
#  batch num:  26 size of:  22
# ++++++ FINISHED LatinBERT/library_super_reduced/plautus/plautus_stichus.txt +++++++++
#   4  su  9
# 2021-08-16 20:05:42.626050: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
# ++++++STARTING:  LatinBERT/library_super_reduced/plautus/plautus_menaechmi.txt
# 49
#
#  batch num:  0 size of:  32
#
#  batch num:  1 size of:  32
#
#  batch num:  2 size of:  32
#
#  batch num:  3 size of:  32
#
#  batch num:  4 size of:  32
#
#  batch num:  5 size of:  32
#
#  batch num:  6 size of:  32
#
#  batch num:  7 size of:  32
#
#  batch num:  8 size of:  32
#
#  batch num:  9 size of:  32
#
#  batch num:  10 size of:  32
#
#  batch num:  11 size of:  32
#
#  batch num:  12 size of:  32
#
#  batch num:  13 size of:  32
#
#  batch num:  14 size of:  32
#
#  batch num:  15 size of:  32
#
#  batch num:  16 size of:  32
#
#  batch num:  17 size of:  32
#
#  batch num:  18 size of:  32
#
#  batch num:  19 size of:  32
#
#  batch num:  20 size of:  32
#
#  batch num:  21 size of:  32
#
#  batch num:  22 size of:  32
#
#  batch num:  23 size of:  32
#
#  batch num:  24 size of:  32
#
#  batch num:  25 size of:  32
#
#  batch num:  26 size of:  32
#
#  batch num:  27 size of:  32
#
#  batch num:  28 size of:  32
#
#  batch num:  29 size of:  32
#
#  batch num:  30 size of:  32
#
#  batch num:  31 size of:  32
#
#  batch num:  32 size of:  32
#
#  batch num:  33 size of:  32
#
#  batch num:  34 size of:  32
#
#  batch num:  35 size of:  32
#
#  batch num:  36 size of:  32
#
#  batch num:  37 size of:  32
#
#  batch num:  38 size of:  32
#
#  batch num:  39 size of:  32
#
#  batch num:  40 size of:  32
#
#  batch num:  41 size of:  32
#
#  batch num:  42 size of:  32
#
#  batch num:  43 size of:  32
#
#  batch num:  44 size of:  32
#
#  batch num:  45 size of:  32
#
#  batch num:  46 size of:  32
#
#  batch num:  47 size of:  32
#
#  batch num:  48 size of:  31
# ++++++ FINISHED LatinBERT/library_super_reduced/plautus/plautus_menaechmi.txt +++++++++
#   5  su  9
# 2021-08-16 20:05:55.840747: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
# ++++++STARTING:  LatinBERT/library_super_reduced/plautus/plautus_cistellaria.txt
# 22
#
#  batch num:  0 size of:  32
#
#  batch num:  1 size of:  32
#
#  batch num:  2 size of:  32
#
#  batch num:  3 size of:  32
#
#  batch num:  4 size of:  32
#
#  batch num:  5 size of:  32
#
#  batch num:  6 size of:  32
#
#  batch num:  7 size of:  32
#
#  batch num:  8 size of:  32
#
#  batch num:  9 size of:  32
#
#  batch num:  10 size of:  32
#
#  batch num:  11 size of:  32
#
#  batch num:  12 size of:  32
#
#  batch num:  13 size of:  32
#
#  batch num:  14 size of:  32
#
#  batch num:  15 size of:  32
#
#  batch num:  16 size of:  32
#
#  batch num:  17 size of:  32
#
#  batch num:  18 size of:  32
#
#  batch num:  19 size of:  32
#
#  batch num:  20 size of:  32
#
#  batch num:  21 size of:  24
# ++++++ FINISHED LatinBERT/library_super_reduced/plautus/plautus_cistellaria.txt +++++++++
#   6  su  9
# 2021-08-16 20:06:08.252770: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
# ++++++STARTING:  LatinBERT/library_super_reduced/plautus/plautus_epidicus.txt
# 33
#
#  batch num:  0 size of:  32
#
#  batch num:  1 size of:  32
#
#  batch num:  2 size of:  32
#
#  batch num:  3 size of:  32
#
#  batch num:  4 size of:  32
#
#  batch num:  5 size of:  32
#
#  batch num:  6 size of:  32
#
#  batch num:  7 size of:  32
#
#  batch num:  8 size of:  32
#
#  batch num:  9 size of:  32
#
#  batch num:  10 size of:  32
#
#  batch num:  11 size of:  32
#
#  batch num:  12 size of:  32
#
#  batch num:  13 size of:  32
#
#  batch num:  14 size of:  32
#
#  batch num:  15 size of:  32
#
#  batch num:  16 size of:  32
#
#  batch num:  17 size of:  32
#
#  batch num:  18 size of:  32
#
#  batch num:  19 size of:  32
#
#  batch num:  20 size of:  32
#
#  batch num:  21 size of:  32
#
#  batch num:  22 size of:  32
#
#  batch num:  23 size of:  32
#
#  batch num:  24 size of:  32
#
#  batch num:  25 size of:  32
#
#  batch num:  26 size of:  32
#
#  batch num:  27 size of:  32
#
#  batch num:  28 size of:  32
#
#  batch num:  29 size of:  32
#
#  batch num:  30 size of:  32
#
#  batch num:  31 size of:  32
#
#  batch num:  32 size of:  20
# ++++++ FINISHED LatinBERT/library_super_reduced/plautus/plautus_epidicus.txt +++++++++
#   7  su  9
# 2021-08-16 20:06:21.462336: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
# ++++++STARTING:  LatinBERT/library_super_reduced/plautus/plautus_persa.txt
# 40
#
#  batch num:  0 size of:  32
#
#  batch num:  1 size of:  32
#
#  batch num:  2 size of:  32
#
#  batch num:  3 size of:  32
#
#  batch num:  4 size of:  32
#
#  batch num:  5 size of:  32
#
#  batch num:  6 size of:  32
#
#  batch num:  7 size of:  32
#
#  batch num:  8 size of:  32
#
#  batch num:  9 size of:  32
#
#  batch num:  10 size of:  32
#
#  batch num:  11 size of:  32
#
#  batch num:  12 size of:  32
#
#  batch num:  13 size of:  32
#
#  batch num:  14 size of:  32
#
#  batch num:  15 size of:  32
#
#  batch num:  16 size of:  32
#
#  batch num:  17 size of:  32
#
#  batch num:  18 size of:  32
#
#  batch num:  19 size of:  32
#
#  batch num:  20 size of:  32
#
#  batch num:  21 size of:  32
#
#  batch num:  22 size of:  32
#
#  batch num:  23 size of:  32
#
#  batch num:  24 size of:  32
#
#  batch num:  25 size of:  32
#
#  batch num:  26 size of:  32
#
#  batch num:  27 size of:  32
#
#  batch num:  28 size of:  32
#
#  batch num:  29 size of:  32
#
#  batch num:  30 size of:  32
#
#  batch num:  31 size of:  32
#
#  batch num:  32 size of:  32
#
#  batch num:  33 size of:  32
#
#  batch num:  34 size of:  32
#
#  batch num:  35 size of:  32
#
#  batch num:  36 size of:  32
#
#  batch num:  37 size of:  32
#
#  batch num:  38 size of:  32
#
#  batch num:  39 size of:  10
# ++++++ FINISHED LatinBERT/library_super_reduced/plautus/plautus_persa.txt +++++++++
#   8  su  9
# 2021-08-16 20:06:34.777461: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
# ++++++STARTING:  LatinBERT/library_super_reduced/plautus/plautus_cas.txt
# 42
#
#  batch num:  0 size of:  32
#
#  batch num:  1 size of:  32
#
#  batch num:  2 size of:  32
#
#  batch num:  3 size of:  32
#
#  batch num:  4 size of:  32
#
#  batch num:  5 size of:  32
#
#  batch num:  6 size of:  32
#
#  batch num:  7 size of:  32
#
#  batch num:  8 size of:  32
#
#  batch num:  9 size of:  32
#
#  batch num:  10 size of:  32
#
#  batch num:  11 size of:  32
#
#  batch num:  12 size of:  32
#
#  batch num:  13 size of:  32
#
#  batch num:  14 size of:  32
#
#  batch num:  15 size of:  32
#
#  batch num:  16 size of:  32
#
#  batch num:  17 size of:  32
#
#  batch num:  18 size of:  32
#
#  batch num:  19 size of:  32
#
#  batch num:  20 size of:  32
#
#  batch num:  21 size of:  32
#
#  batch num:  22 size of:  32
#
#  batch num:  23 size of:  32
#
#  batch num:  24 size of:  32
#
#  batch num:  25 size of:  32
#
#  batch num:  26 size of:  32
#
#  batch num:  27 size of:  32
#
#  batch num:  28 size of:  32
#
#  batch num:  29 size of:  32
#
#  batch num:  30 size of:  32
#
#  batch num:  31 size of:  32
#
#  batch num:  32 size of:  32
#
#  batch num:  33 size of:  32
#
#  batch num:  34 size of:  32
#
#  batch num:  35 size of:  32
#
#  batch num:  36 size of:  32
#
#  batch num:  37 size of:  32
#
#  batch num:  38 size of:  32
#
#  batch num:  39 size of:  32
#
#  batch num:  40 size of:  32
#
#  batch num:  41 size of:  25
# ++++++ FINISHED LatinBERT/library_super_reduced/plautus/plautus_cas.txt +++++++++
#   9  su  9
# 2021-08-16 20:06:47.602325: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
# ++++++STARTING:  LatinBERT/library_super_reduced/plautus/plautus_truculentus.txt
# 32
#
#  batch num:  0 size of:  32
#
#  batch num:  1 size of:  32
#
#  batch num:  2 size of:  32
#
#  batch num:  3 size of:  32
#
#  batch num:  4 size of:  32
#
#  batch num:  5 size of:  32
#
#  batch num:  6 size of:  32
#
#  batch num:  7 size of:  32
#
#  batch num:  8 size of:  32
#
#  batch num:  9 size of:  32
#
#  batch num:  10 size of:  32
#
#  batch num:  11 size of:  32
#
#  batch num:  12 size of:  32
#
#  batch num:  13 size of:  32
#
#  batch num:  14 size of:  32
#
#  batch num:  15 size of:  32
#
#  batch num:  16 size of:  32
#
#  batch num:  17 size of:  32
#
#  batch num:  18 size of:  32
#
#  batch num:  19 size of:  32
#
#  batch num:  20 size of:  32
#
#  batch num:  21 size of:  32
#
#  batch num:  22 size of:  32
#
#  batch num:  23 size of:  32
#
#  batch num:  24 size of:  32
#
#  batch num:  25 size of:  32
#
#  batch num:  26 size of:  32
#
#  batch num:  27 size of:  32
#
#  batch num:  28 size of:  32
#
#  batch num:  29 size of:  32
#
#  batch num:  30 size of:  32
#
#  batch num:  31 size of:  30
# ++++++ FINISHED LatinBERT/library_super_reduced/plautus/plautus_truculentus.txt +++++++++
#   10  su  9
# 2021-08-16 20:07:00.957144: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
# ++++++STARTING:  LatinBERT/library_super_reduced/plautus/plautus_pseudolus.txt
# 53
#
#  batch num:  0 size of:  32
#
#  batch num:  1 size of:  32
#
#  batch num:  2 size of:  32
#
#  batch num:  3 size of:  32
#
#  batch num:  4 size of:  32
#
#  batch num:  5 size of:  32
#
#  batch num:  6 size of:  32
#
#  batch num:  7 size of:  32
#
#  batch num:  8 size of:  32
#
#  batch num:  9 size of:  32
#
#  batch num:  10 size of:  32
#
#  batch num:  11 size of:  32
#
#  batch num:  12 size of:  32
#
#  batch num:  13 size of:  32
#
#  batch num:  14 size of:  32
#
#  batch num:  15 size of:  32
#
#  batch num:  16 size of:  32
#
#  batch num:  17 size of:  32
#
#  batch num:  18 size of:  32
#
#  batch num:  19 size of:  32
#
#  batch num:  20 size of:  32
#
#  batch num:  21 size of:  32
#
#  batch num:  22 size of:  32
#
#  batch num:  23 size of:  32
#
#  batch num:  24 size of:  32
#
#  batch num:  25 size of:  32
#
#  batch num:  26 size of:  32
#
#  batch num:  27 size of:  32
#
#  batch num:  28 size of:  32
#
#  batch num:  29 size of:  32
#
#  batch num:  30 size of:  32
#
#  batch num:  31 size of:  32
#
#  batch num:  32 size of:  32
#
#  batch num:  33 size of:  32
#
#  batch num:  34 size of:  32
#
#  batch num:  35 size of:  32
#
#  batch num:  36 size of:  32
#
#  batch num:  37 size of:  32
#
#  batch num:  38 size of:  32
#
#  batch num:  39 size of:  32
#
#  batch num:  40 size of:  32
#
#  batch num:  41 size of:  32
#
#  batch num:  42 size of:  32
#
#  batch num:  43 size of:  32
#
#  batch num:  44 size of:  32
#
#  batch num:  45 size of:  32
#
#  batch num:  46 size of:  32
#
#  batch num:  47 size of:  32
#
#  batch num:  48 size of:  32
#
#  batch num:  49 size of:  32
#
#  batch num:  50 size of:  32
#
#  batch num:  51 size of:  32
#
#  batch num:  52 size of:  21
# ++++++ FINISHED LatinBERT/library_super_reduced/plautus/plautus_pseudolus.txt +++++++++
#   11  su  9
# 2021-08-16 20:07:14.742634: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
# ++++++STARTING:  LatinBERT/library_super_reduced/plautus/plautus_trinummus.txt
# 35
#
#  batch num:  0 size of:  32
#
#  batch num:  1 size of:  32
#
#  batch num:  2 size of:  32
#
#  batch num:  3 size of:  32
#
#  batch num:  4 size of:  32
#
#  batch num:  5 size of:  32
#
#  batch num:  6 size of:  32
#
#  batch num:  7 size of:  32
#
#  batch num:  8 size of:  32
#
#  batch num:  9 size of:  32
#
#  batch num:  10 size of:  32
#
#  batch num:  11 size of:  32
#
#  batch num:  12 size of:  32
#
#  batch num:  13 size of:  32
#
#  batch num:  14 size of:  32
#
#  batch num:  15 size of:  32
#
#  batch num:  16 size of:  32
#
#  batch num:  17 size of:  32
#
#  batch num:  18 size of:  32
#
#  batch num:  19 size of:  32
#
#  batch num:  20 size of:  32
#
#  batch num:  21 size of:  32
#
#  batch num:  22 size of:  32
#
#  batch num:  23 size of:  32
#
#  batch num:  24 size of:  32
#
#  batch num:  25 size of:  32
#
#  batch num:  26 size of:  32
#
#  batch num:  27 size of:  32
#
#  batch num:  28 size of:  32
#
#  batch num:  29 size of:  32
#
#  batch num:  30 size of:  32
#
#  batch num:  31 size of:  32
#
#  batch num:  32 size of:  32
#
#  batch num:  33 size of:  32
#
#  batch num:  34 size of:  29
# ++++++ FINISHED LatinBERT/library_super_reduced/plautus/plautus_trinummus.txt +++++++++
#   12  su  9
# 2021-08-16 20:07:28.697906: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
# ++++++STARTING:  LatinBERT/library_super_reduced/plautus/plautus_bacchides.txt
# 40
#
#  batch num:  0 size of:  32
#
#  batch num:  1 size of:  32
#
#  batch num:  2 size of:  32
#
#  batch num:  3 size of:  32
#
#  batch num:  4 size of:  32
#
#  batch num:  5 size of:  32
#
#  batch num:  6 size of:  32
#
#  batch num:  7 size of:  32
#
#  batch num:  8 size of:  32
#
#  batch num:  9 size of:  32
#
#  batch num:  10 size of:  32
# Traceback (most recent call last):
#   File "LatinBERT/text_to_pickle.py", line 267, in <module>
#     berts=model.forward(batched_data[b], attention_mask=batched_mask[b], transforms=batched_transforms[b])
#   File "LatinBERT/text_to_pickle.py", line 224, in forward
#     sequence_outputs, pooled_outputs = self.bert.forward(input_ids, token_type_ids=None, attention_mask=attention_mask)
#   File "/usr/local/lib/python3.7/dist-packages/transformers/modeling_bert.py", line 835, in forward
#     return_dict=return_dict,
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 1051, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/transformers/modeling_bert.py", line 490, in forward
#     output_attentions,
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 1051, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/transformers/modeling_bert.py", line 412, in forward
#     output_attentions=output_attentions,
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 1051, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/transformers/modeling_bert.py", line 349, in forward
#     output_attentions,
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 1051, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/transformers/modeling_bert.py", line 285, in forward
#     context_layer = torch.matmul(attention_probs, value_layer)
# KeyboardInterrupt
#   13  su  9
# 2021-08-16 20:07:41.051227: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
# ++++++STARTING:  LatinBERT/library_super_reduced/plautus/plautus_asinaria.txt
# 36
#
#  batch num:  0 size of:  32
#
#  batch num:  1 size of:  32
#
#  batch num:  2 size of:  32
#
#  batch num:  3 size of:  32
#
#  batch num:  4 size of:  32
#
#  batch num:  5 size of:  32
#
#  batch num:  6 size of:  32
#
#  batch num:  7 size of:  32
#
#  batch num:  8 size of:  32
#
#  batch num:  9 size of:  32
#
#  batch num:  10 size of:  32
#
#  batch num:  11 size of:  32
#
#  batch num:  12 size of:  32
#
#  batch num:  13 size of:  32
#
#  batch num:  14 size of:  32
#
#  batch num:  15 size of:  32
#
#  batch num:  16 size of:  32
#
#  batch num:  17 size of:  32
#
#  batch num:  18 size of:  32
#
#  batch num:  19 size of:  32
#
#  batch num:  20 size of:  32
#
#  batch num:  21 size of:  32
#
#  batch num:  22 size of:  32
#
#  batch num:  23 size of:  32
#
#  batch num:  24 size of:  32
#
#  batch num:  25 size of:  32
#
#  batch num:  26 size of:  32
#
#  batch num:  27 size of:  32
#
#  batch num:  28 size of:  32
#
#  batch num:  29 size of:  32
#
#  batch num:  30 size of:  32
#
#  batch num:  31 size of:  32
#
#  batch num:  32 size of:  32
#
#  batch num:  33 size of:  32
#
#  batch num:  34 size of:  32
#
#  batch num:  35 size of:  2
# ++++++ FINISHED LatinBERT/library_super_reduced/plautus/plautus_asinaria.txt +++++++++
#   14  su  9
# 2021-08-16 20:07:54.072110: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
# ++++++STARTING:  LatinBERT/library_super_reduced/plautus/plautus_captivi.txt
# 28
#
#  batch num:  0 size of:  32
#
#  batch num:  1 size of:  32
#
#  batch num:  2 size of:  32
#
#  batch num:  3 size of:  32
#
#  batch num:  4 size of:  32
#
#  batch num:  5 size of:  32
#
#  batch num:  6 size of:  32
#
#  batch num:  7 size of:  32
#
#  batch num:  8 size of:  32
#
#  batch num:  9 size of:  32
#
#  batch num:  10 size of:  32
#
#  batch num:  11 size of:  32
#
#  batch num:  12 size of:  32
#
#  batch num:  13 size of:  32
#
#  batch num:  14 size of:  32
#
#  batch num:  15 size of:  32
#
#  batch num:  16 size of:  32
#
#  batch num:  17 size of:  32
#
#  batch num:  18 size of:  32
#
#  batch num:  19 size of:  32
#
#  batch num:  20 size of:  32
#
#  batch num:  21 size of:  32
#
#  batch num:  22 size of:  32
#
#  batch num:  23 size of:  32
#
#  batch num:  24 size of:  32
#
#  batch num:  25 size of:  32
#
#  batch num:  26 size of:  32
#
#  batch num:  27 size of:  4
# ++++++ FINISHED LatinBERT/library_super_reduced/plautus/plautus_captivi.txt +++++++++
#   15  su  9
# 2021-08-16 20:08:07.015741: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
# ++++++STARTING:  LatinBERT/library_super_reduced/plautus/plautus_mostellaria.txt
# 53
#
#  batch num:  0 size of:  32
#
#  batch num:  1 size of:  32
#
#  batch num:  2 size of:  32
#
#  batch num:  3 size of:  32
#
#  batch num:  4 size of:  32
#
#  batch num:  5 size of:  32
#
#  batch num:  6 size of:  32
#
#  batch num:  7 size of:  32
#
#  batch num:  8 size of:  32
#
#  batch num:  9 size of:  32
#
#  batch num:  10 size of:  32
#
#  batch num:  11 size of:  32
#
#  batch num:  12 size of:  32
#
#  batch num:  13 size of:  32
#
#  batch num:  14 size of:  32
#
#  batch num:  15 size of:  32
#
#  batch num:  16 size of:  32
#
#  batch num:  17 size of:  32
#
#  batch num:  18 size of:  32
#
#  batch num:  19 size of:  32
#
#  batch num:  20 size of:  32
#
#  batch num:  21 size of:  32
#
#  batch num:  22 size of:  32
#
#  batch num:  23 size of:  32
#
#  batch num:  24 size of:  32
#
#  batch num:  25 size of:  32
#
#  batch num:  26 size of:  32
#
#  batch num:  27 size of:  32
#
#  batch num:  28 size of:  32
#
#  batch num:  29 size of:  32
#
#  batch num:  30 size of:  32
#
#  batch num:  31 size of:  32
#
#  batch num:  32 size of:  32
#
#  batch num:  33 size of:  32
#
#  batch num:  34 size of:  32
#
#  batch num:  35 size of:  32
#
#  batch num:  36 size of:  32
#
#  batch num:  37 size of:  32
#
#  batch num:  38 size of:  32
#
#  batch num:  39 size of:  32
#
#  batch num:  40 size of:  32
#
#  batch num:  41 size of:  32
#
#  batch num:  42 size of:  32
#
#  batch num:  43 size of:  32
#
#  batch num:  44 size of:  32
#
#  batch num:  45 size of:  32
#
#  batch num:  46 size of:  32
#
#  batch num:  47 size of:  32
#
#  batch num:  48 size of:  32
#
#  batch num:  49 size of:  32
#
#  batch num:  50 size of:  32
#
#  batch num:  51 size of:  32
#
#  batch num:  52 size of:  11
# ++++++ FINISHED LatinBERT/library_super_reduced/plautus/plautus_mostellaria.txt +++++++++
#   16  su  9
# 2021-08-16 20:08:20.452145: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
# ++++++STARTING:  LatinBERT/library_super_reduced/plautus/plautus_miles.txt
# 48
#
#  batch num:  0 size of:  32
#
#  batch num:  1 size of:  32
#
#  batch num:  2 size of:  32
#
#  batch num:  3 size of:  32
#
#  batch num:  4 size of:  32
#
#  batch num:  5 size of:  32
#
#  batch num:  6 size of:  32
#
#  batch num:  7 size of:  32
#
#  batch num:  8 size of:  32
#
#  batch num:  9 size of:  32
#
#  batch num:  10 size of:  32
#
#  batch num:  11 size of:  32
#
#  batch num:  12 size of:  32
#
#  batch num:  13 size of:  32
#
#  batch num:  14 size of:  32
#
#  batch num:  15 size of:  32
#
#  batch num:  16 size of:  32
#
#  batch num:  17 size of:  32
#
#  batch num:  18 size of:  32
#
#  batch num:  19 size of:  32
#
#  batch num:  20 size of:  32
#
#  batch num:  21 size of:  32
#
#  batch num:  22 size of:  32
#
#  batch num:  23 size of:  32
#
#  batch num:  24 size of:  32
#
#  batch num:  25 size of:  32
#
#  batch num:  26 size of:  32
#
#  batch num:  27 size of:  32
#
#  batch num:  28 size of:  32
#
#  batch num:  29 size of:  32
#
#  batch num:  30 size of:  32
#
#  batch num:  31 size of:  32
#
#  batch num:  32 size of:  32
#
#  batch num:  33 size of:  32
#
#  batch num:  34 size of:  32
#
#  batch num:  35 size of:  32
#
#  batch num:  36 size of:  32
#
#  batch num:  37 size of:  32
#
#  batch num:  38 size of:  32
#
#  batch num:  39 size of:  32
#
#  batch num:  40 size of:  32
#
#  batch num:  41 size of:  32
#
#  batch num:  42 size of:  32
#
#  batch num:  43 size of:  32
#
#  batch num:  44 size of:  32
#
#  batch num:  45 size of:  32
#
#  batch num:  46 size of:  32
#
#  batch num:  47 size of:  30
# ++++++ FINISHED LatinBERT/library_super_reduced/plautus/plautus_miles.txt +++++++++
#   17  su  9
# 2021-08-16 20:08:35.415912: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
# ++++++STARTING:  LatinBERT/library_super_reduced/plautus/plautus_mercator.txt
# 40
#
#  batch num:  0 size of:  32
#
#  batch num:  1 size of:  32
#
#  batch num:  2 size of:  32
#
#  batch num:  3 size of:  32
#
#  batch num:  4 size of:  32
#
#  batch num:  5 size of:  32
#
#  batch num:  6 size of:  32
#
#  batch num:  7 size of:  32
#
#  batch num:  8 size of:  32
#
#  batch num:  9 size of:  32
#
#  batch num:  10 size of:  32
#
#  batch num:  11 size of:  32
#
#  batch num:  12 size of:  32
#
#  batch num:  13 size of:  32
#
#  batch num:  14 size of:  32
#
#  batch num:  15 size of:  32
#
#  batch num:  16 size of:  32
#
#  batch num:  17 size of:  32
#
#  batch num:  18 size of:  32
#
#  batch num:  19 size of:  32
#
#  batch num:  20 size of:  32
#
#  batch num:  21 size of:  32
#
#  batch num:  22 size of:  32
#
#  batch num:  23 size of:  32
#
#  batch num:  24 size of:  32
#
#  batch num:  25 size of:  32
#
#  batch num:  26 size of:  32
#
#  batch num:  27 size of:  32
#
#  batch num:  28 size of:  32
#
#  batch num:  29 size of:  32
#
#  batch num:  30 size of:  32
#
#  batch num:  31 size of:  32
#
#  batch num:  32 size of:  32
#
#  batch num:  33 size of:  32
#
#  batch num:  34 size of:  32
#
#  batch num:  35 size of:  32
#
#  batch num:  36 size of:  32
#
#  batch num:  37 size of:  32
#
#  batch num:  38 size of:  32
#
#  batch num:  39 size of:  6
# ++++++ FINISHED LatinBERT/library_super_reduced/plautus/plautus_mercator.txt +++++++++
#   18  su  9
# 2021-08-16 20:08:48.969419: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
# ++++++STARTING:  LatinBERT/library_super_reduced/plautus/plautus_rudens.txt
# 44
#
#  batch num:  0 size of:  32
#
#  batch num:  1 size of:  32
#
#  batch num:  2 size of:  32
#
#  batch num:  3 size of:  32
#
#  batch num:  4 size of:  32
#
#  batch num:  5 size of:  32
#
#  batch num:  6 size of:  32
#
#  batch num:  7 size of:  32
#
#  batch num:  8 size of:  32
#
#  batch num:  9 size of:  32
#
#  batch num:  10 size of:  32
#
#  batch num:  11 size of:  32
#
#  batch num:  12 size of:  32
#
#  batch num:  13 size of:  32
#
#  batch num:  14 size of:  32
#
#  batch num:  15 size of:  32
#
#  batch num:  16 size of:  32
#
#  batch num:  17 size of:  32
#
#  batch num:  18 size of:  32
#
#  batch num:  19 size of:  32
#
#  batch num:  20 size of:  32
#
#  batch num:  21 size of:  32
#
#  batch num:  22 size of:  32
#
#  batch num:  23 size of:  32
#
#  batch num:  24 size of:  32
#
#  batch num:  25 size of:  32
#
#  batch num:  26 size of:  32
#
#  batch num:  27 size of:  32
#
#  batch num:  28 size of:  32
#
#  batch num:  29 size of:  32
#
#  batch num:  30 size of:  32
#
#  batch num:  31 size of:  32
#
#  batch num:  32 size of:  32
#
#  batch num:  33 size of:  32
#
#  batch num:  34 size of:  32
#
#  batch num:  35 size of:  32
#
#  batch num:  36 size of:  32
#
#  batch num:  37 size of:  32
#
#  batch num:  38 size of:  32
#
#  batch num:  39 size of:  32
#
#  batch num:  40 size of:  32
#
#  batch num:  41 size of:  32
#
#  batch num:  42 size of:  32
#
#  batch num:  43 size of:  6
# ++++++ FINISHED LatinBERT/library_super_reduced/plautus/plautus_rudens.txt +++++++++
#   19  su  9
# 2021-08-16 20:09:03.407482: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
# ++++++STARTING:  LatinBERT/library_super_reduced/plautus/plautus_poenulus.txt
# 54
#
#  batch num:  0 size of:  32
#
#  batch num:  1 size of:  32
#
#  batch num:  2 size of:  32
#
#  batch num:  3 size of:  32
#
#  batch num:  4 size of:  32
#
#  batch num:  5 size of:  32
#
#  batch num:  6 size of:  32
#
#  batch num:  7 size of:  32
#
#  batch num:  8 size of:  32
#
#  batch num:  9 size of:  32
#
#  batch num:  10 size of:  32
#
#  batch num:  11 size of:  32
#
#  batch num:  12 size of:  32
#
#  batch num:  13 size of:  32
#
#  batch num:  14 size of:  32
#
#  batch num:  15 size of:  32
#
#  batch num:  16 size of:  32
#
#  batch num:  17 size of:  32
#
#  batch num:  18 size of:  32
#
#  batch num:  19 size of:  32
#
#  batch num:  20 size of:  32
#
#  batch num:  21 size of:  32
#
#  batch num:  22 size of:  32
#
#  batch num:  23 size of:  32
#
#  batch num:  24 size of:  32
#
#  batch num:  25 size of:  32
#
#  batch num:  26 size of:  32
#
#  batch num:  27 size of:  32
#
#  batch num:  28 size of:  32
#
#  batch num:  29 size of:  32
#
#  batch num:  30 size of:  32
#
#  batch num:  31 size of:  32
#
#  batch num:  32 size of:  32
#
#  batch num:  33 size of:  32
#
#  batch num:  34 size of:  32
#
#  batch num:  35 size of:  32
#
#  batch num:  36 size of:  32
#
#  batch num:  37 size of:  32
#
#  batch num:  38 size of:  32
#
#  batch num:  39 size of:  32
#
#  batch num:  40 size of:  32
#
#  batch num:  41 size of:  32
#
#  batch num:  42 size of:  32
#
#  batch num:  43 size of:  32
#
#  batch num:  44 size of:  32
#
#  batch num:  45 size of:  32
#
#  batch num:  46 size of:  32
#
#  batch num:  47 size of:  32
#
#  batch num:  48 size of:  32
#
#  batch num:  49 size of:  32
#
#  batch num:  50 size of:  32
#
#  batch num:  51 size of:  32
#
#  batch num:  52 size of:  32
#
#  batch num:  53 size of:  31
# ++++++ FINISHED LatinBERT/library_super_reduced/plautus/plautus_poenulus.txt +++++++++
#   20  su  9
# 2021-08-16 20:09:18.229394: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
# ++++++STARTING:  LatinBERT/library_super_reduced/plautus/plautus_aulularia.txt
# 24
#
#  batch num:  0 size of:  32
#
#  batch num:  1 size of:  32
#
#  batch num:  2 size of:  32
#
#  batch num:  3 size of:  32
#
#  batch num:  4 size of:  32
#
#  batch num:  5 size of:  32
#
#  batch num:  6 size of:  32
#
#  batch num:  7 size of:  32
#
#  batch num:  8 size of:  32
#
#  batch num:  9 size of:  32
#
#  batch num:  10 size of:  32
#
#  batch num:  11 size of:  32
#
#  batch num:  12 size of:  32
#
#  batch num:  13 size of:  32
#
#  batch num:  14 size of:  32
#
#  batch num:  15 size of:  32
#
#  batch num:  16 size of:  32
#
#  batch num:  17 size of:  32
#
#  batch num:  18 size of:  32
#
#  batch num:  19 size of:  32
#
#  batch num:  20 size of:  32
#
#  batch num:  21 size of:  32
#
#  batch num:  22 size of:  32
#
#  batch num:  23 size of:  16
# ++++++ FINISHED LatinBERT/library_super_reduced/plautus/plautus_aulularia.txt +++++++++
#   21  su  9
# 2021-08-16 20:09:30.792000: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
# ++++++STARTING:  LatinBERT/library_super_reduced/plautus/plautus_curculio.txt
# 25
#
#  batch num:  0 size of:  32
#
#  batch num:  1 size of:  32
#
#  batch num:  2 size of:  32
#
#  batch num:  3 size of:  32
#
#  batch num:  4 size of:  32
#
#  batch num:  5 size of:  32
#
#  batch num:  6 size of:  32
#
#  batch num:  7 size of:  32
#
#  batch num:  8 size of:  32
#
#  batch num:  9 size of:  32
#
#  batch num:  10 size of:  32
#
#  batch num:  11 size of:  32
#
#  batch num:  12 size of:  32
#
#  batch num:  13 size of:  32
#
#  batch num:  14 size of:  32
#
#  batch num:  15 size of:  32
#
#  batch num:  16 size of:  32
#
#  batch num:  17 size of:  32
#
#  batch num:  18 size of:  32
#
#  batch num:  19 size of:  32
#
#  batch num:  20 size of:  32
#
#  batch num:  21 size of:  32
#
#  batch num:  22 size of:  32
#
#  batch num:  23 size of:  32
#
#  batch num:  24 size of:  24
# ++++++ FINISHED LatinBERT/library_super_reduced/plautus/plautus_curculio.txt +++++++++
#   22  su  9
# 2021-08-16 20:09:43.258450: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
# ++++++STARTING:  LatinBERT/library_super_reduced/vergil/vergil_geo2.txt
# 5
#
#  batch num:  0 size of:  32
#
#  batch num:  1 size of:  32
#
#  batch num:  2 size of:  32
#
#  batch num:  3 size of:  32
#
#  batch num:  4 size of:  17
# ++++++ FINISHED LatinBERT/library_super_reduced/vergil/vergil_geo2.txt +++++++++
#   23  su  9
# 2021-08-16 20:09:55.130476: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
# ++++++STARTING:  LatinBERT/library_super_reduced/vergil/vergil_geo4.txt
# 5
#
#  batch num:  0 size of:  32
#
#  batch num:  1 size of:  32
#
#  batch num:  2 size of:  32
#
#  batch num:  3 size of:  32
#
#  batch num:  4 size of:  21
# ++++++ FINISHED LatinBERT/library_super_reduced/vergil/vergil_geo4.txt +++++++++
#   24  su  9
# 2021-08-16 20:10:07.931352: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
# ++++++STARTING:  LatinBERT/library_super_reduced/vergil/vergil_ec6.txt
# 1
#
#  batch num:  0 size of:  32
# ++++++ FINISHED LatinBERT/library_super_reduced/vergil/vergil_ec6.txt +++++++++
#   25  su  9
# 2021-08-16 20:10:20.143350: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
# ++++++STARTING:  LatinBERT/library_super_reduced/vergil/vergil_aen12.txt
# 9
#
#  batch num:  0 size of:  32
#
#  batch num:  1 size of:  32
#
#  batch num:  2 size of:  32
#
#  batch num:  3 size of:  32
#
#  batch num:  4 size of:  32
#
#  batch num:  5 size of:  32
#
#  batch num:  6 size of:  32
#
#  batch num:  7 size of:  32
#
#  batch num:  8 size of:  15
# ++++++ FINISHED LatinBERT/library_super_reduced/vergil/vergil_aen12.txt +++++++++
#   26  su  9
# 2021-08-16 20:10:32.772246: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
# ++++++STARTING:  LatinBERT/library_super_reduced/vergil/vergil_aen4.txt
# 8
#
#  batch num:  0 size of:  32
#
#  batch num:  1 size of:  32
#
#  batch num:  2 size of:  32
#
#  batch num:  3 size of:  32
#
#  batch num:  4 size of:  32
#
#  batch num:  5 size of:  32
#
#  batch num:  6 size of:  32
#
#  batch num:  7 size of:  26
# ++++++ FINISHED LatinBERT/library_super_reduced/vergil/vergil_aen4.txt +++++++++
#   27  su  9
# 2021-08-16 20:10:44.864409: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
# ++++++STARTING:  LatinBERT/library_super_reduced/vergil/vergil_aen2.txt
# 9
#
#  batch num:  0 size of:  32
#
#  batch num:  1 size of:  32
#
#  batch num:  2 size of:  32
#
#  batch num:  3 size of:  32
#
#  batch num:  4 size of:  32
#
#  batch num:  5 size of:  32
#
#  batch num:  6 size of:  32
#
#  batch num:  7 size of:  32
#
#  batch num:  8 size of:  11
# ++++++ FINISHED LatinBERT/library_super_reduced/vergil/vergil_aen2.txt +++++++++
#   28  su  9
# 2021-08-16 20:10:57.046425: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
#
# ++++++STARTING:  LatinBERT/library_super_reduced/vergil/vergil_aen11.txt
# 9
#
#  batch num:  0 size of:  32
#
#  batch num:  1 size of:  32
#
#  batch num:  2 size of:  32
#
#  batch num:  3 size of:  32
#
#  batch num:  4 size of:  32
#
#  batch num:  5 size of:  32
#
#  batch num:  6 size of:  32
#
#  batch num:  7 size of:  32
#
#  batch num:  8 size of:  30
# ++++++ FINISHED LatinBERT/library_super_reduced/vergil/vergil_aen11.txt +++++++++
#   29  su  9
# Traceback (most recent call last):
#   File "LatinBERT/text_to_pickle.py", line 2, in <module>
#     from cltk.tokenizers.lat.lat import LatinWordTokenizer as WordTokenizer
#   File "/usr/local/lib/python3.7/dist-packages/cltk/__init__.py", line 5, in <module>
#     from .nlp import NLP
#   File "/usr/local/lib/python3.7/dist-packages/cltk/nlp.py", line 9, in <module>
#     from cltk.languages.pipelines import (
#   File "/usr/local/lib/python3.7/dist-packages/cltk/languages/pipelines.py", line 23, in <module>
#     from cltk.embeddings.processes import (
#   File "/usr/local/lib/python3.7/dist-packages/cltk/embeddings/__init__.py", line 3, in <module>
#     from .embeddings import *
#   File "/usr/local/lib/python3.7/dist-packages/cltk/embeddings/embeddings.py", line 24, in <module>
#     from gensim import models  # type: ignore
#   File "/usr/local/lib/python3.7/dist-packages/gensim/__init__.py", line 5, in <module>
#     from gensim import parsing, corpora, matutils, interfaces, models, similarities, summarization, utils  # noqa:F401
#   File "/usr/local/lib/python3.7/dist-packages/gensim/parsing/__init__.py", line 4, in <module>
#     from .preprocessing import (remove_stopwords, strip_punctuation, strip_punctuation2,  # noqa:F401
#   File "/usr/local/lib/python3.7/dist-packages/gensim/parsing/preprocessing.py", line 42, in <module>
#     from gensim import utils
#   File "/usr/local/lib/python3.7/dist-packages/gensim/utils.py", line 45, in <module>
#     from smart_open import open
#   File "/usr/local/lib/python3.7/dist-packages/smart_open/__init__.py", line 34, in <module>
#     from .smart_open_lib import open, parse_uri, smart_open, register_compressor  # noqa: E402
#   File "/usr/local/lib/python3.7/dist-packages/smart_open/smart_open_lib.py", line 35, in <module>
#     from smart_open import doctools
#   File "/usr/local/lib/python3.7/dist-packages/smart_open/doctools.py", line 21, in <module>
#     from . import transport
#   File "/usr/local/lib/python3.7/dist-packages/smart_open/transport.py", line 98, in <module>
#     register_transport('smart_open.gcs')
#   File "/usr/local/lib/python3.7/dist-packages/smart_open/transport.py", line 49, in register_transport
#     submodule = importlib.import_module(submodule)
#   File "/usr/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/usr/local/lib/python3.7/dist-packages/smart_open/gcs.py", line 16, in <module>
#     import google.cloud.storage
#   File "/usr/local/lib/python3.7/dist-packages/google/cloud/storage/__init__.py", line 36, in <module>
#     __version__ = get_distribution("google-cloud-storage").version
#   File "/usr/local/lib/python3.7/dist-packages/pkg_resources/__init__.py", line 466, in get_distribution
#     dist = get_provider(dist)
#   File "/usr/local/lib/python3.7/dist-packages/pkg_resources/__init__.py", line 342, in get_provider
#     return working_set.find(moduleOrReq) or require(str(moduleOrReq))[0]
#   File "/usr/local/lib/python3.7/dist-packages/pkg_resources/__init__.py", line 626, in find
#     if dist is not None and dist not in req:
#   File "/usr/local/lib/python3.7/dist-packages/pkg_resources/__init__.py", line 3129, in __contains__
#     return self.specifier.contains(item, prereleases=True)
#   File "/usr/local/lib/python3.7/dist-packages/pkg_resources/_vendor/packaging/specifiers.py", line 789, in contains
#     item = parse(item)
#   File "/usr/local/lib/python3.7/dist-packages/pkg_resources/_vendor/packaging/version.py", line 56, in parse
#     return Version(version)
#   File "/usr/local/lib/python3.7/dist-packages/pkg_resources/_vendor/packaging/version.py", line 298, in __init__
#     self._version.local,
#   File "/usr/local/lib/python3.7/dist-packages/pkg_resources/_vendor/packaging/version.py", line 490, in _cmpkey
#     reversed(list(itertools.dropwhile(lambda x: x == 0, reversed(release))))
# KeyboardInterrupt
# ^C

# %% [markdown]
# # DOWNLOAD PICKLE FILES

# %%
import os,pickle
from google.colab import files

for file in os.listdir('pickle'):
  files.download('pickle/'+file)
