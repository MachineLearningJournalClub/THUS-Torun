# %% [markdown]
# # PREPARAZIONE DATI

# %%
import pickle
import os
import numpy as np
import umap
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
import umap.plot

# %%
source='/home/wsojka00/Desktop/LatinBERT/pickle'

# %%
data={}

# %%
def get_author(filename):
    pos1 = filename.find('_')
    return filename[:pos1]

authors=[]
for f in os.listdir(source):
    authors.append(get_author(f))
authors
# Out:
# ['abelard',
#  'gallus',
#  'gfAuth',
#  'liutprand',
#  'malmesbury',
#  'monachus',
#  'otto',
#  'poitiers',
#  'raoul',
#  'rupert',
#  'malmesbury',
#  'cosmas',
#  'deExpAuth',
#  'guibert',
#  'malaterra',
#  'otloh',
#  'suger',
#  'thietmar',
#  'galbert']

# %%
for author, file in zip(authors,os.listdir(source)):
    dbfile = open(source+'/'+file,'rb')     
    data[author]=pickle.load(dbfile)

# %%
source='/home/wsojka00/Desktop/LatinBERT/pickle_word/'
import pickle

# %%
dbfile = open(source+'abelard_consol','rb')     
data=pickle.load(dbfile)

# %%
len(data[3])
# Out:
# 30

# %%
for f in os.listdir('/home/wsojka00/Desktop/LatinBERT/corpus0'):
    file=f
    nome=file.replace(" ", "_")
    os.rename(f,'/home/wsojka00/Desktop/LatinBERT/corpus0/'+nome)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-43-1337be722514> in <module>
#       2     file=f
#       3     nome=file.replace(" ", "_")
# ----> 4     os.rename(f,'/home/wsojka00/Desktop/LatinBERT/corpus0/'+nome)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'abelard consol.txt' -> '/home/wsojka00/Desktop/LatinBERT/corpus0/abelard_consol.txt'

# %%
f='ciao come '
f.replace(" ", "_")
# Out:
# 'ciao_come_'

# %%
#salvataggio di tutti gli autori in un pickle file
#dbfile = open('AUTORI', 'wb')
#pickle.dump(data, dbfile)                     
#dbfile.close()

# %%
#voglio una funzione che metta insieme i token degli autori che mi interessano
def function(listauthor):
    token=[]
    auth=[]
    for author in listauthor:
        for key in data[author]:
            token.append(data[author][key][2])
            auth.append(author)
    token=np.array(token)
    auth=np.array(auth)
    return token,auth

# %%
listauthor=authors
X,auth=function(['abelard', 'gfAuth', 'liutprand', 'malmesbury', 'monachus', 'otto', 'poitiers', 'raoul', 
                 'rupert', 'malmesbury','otloh', 'suger', 
                 'thietmar', 'galbert'])

# %%
gallus,_=function(['gallus'])

# %%
X.shape,auth.shape
# Out:
# ((24201, 768), (24201,))

# %%
listauthor=['monachus','gallus']

X,auth=function(listauthor)
X.shape
# Out:
# (1858, 768)

# %%
mapper = umap.UMAP(n_components=2,metric='euclidean', n_neighbors=100,min_dist=0.05).fit(X)

umap.plot.points(mapper, labels=np.array(auth))

# %%
umap.plot.points(mapper, labels=np.array(auth))
# Out:
# <AxesSubplot:>

# %%
umap.plot.connectivity(mapper, show_points=True)
# Out:
# <AxesSubplot:>

# %%
mapper = umap.UMAP(n_components=2,metric='mahalanobis', n_neighbors=100,min_dist=0.1).fit(X)
umap.plot.points(mapper, labels=np.array(auth))

# %%
neighbours=[100]
distances=[0,0.01,0.1,0.5,1]

for neighbour in neighbours:
    for dist in distances:
        mapper = umap.UMAP(n_components=2,metric='euclidean', n_neighbors=neighbour,min_dist=dist).fit(X)
        umap.plot.points(mapper, labels=auth)
